# %% [markdown]
# ## ChromaDB connection and load data

# %%
from IPython.display import display, clear_output

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '../../'))
sys.path.append(project_root)

# %%
import chromadb
import pandas as pd
import json
from copy import deepcopy
from rag.core.utils.config_loader import ConfigLoader

# %%
class ChromaSearcher:
    """
    A class to create ChromaDB collections from given specifics and to search in these collections.
    """

    def __init__(self):
        """
        Initialization of ChromaDB client. Requires host, port, and embedding model from config.
        """
        config_loader = ConfigLoader()
        config = config_loader.load_config()
        self.host = config_loader.get_host()
        self.port = config_loader.get_port()
        self.embedding_model = config_loader.get_embedding_model()
        self.embedding_function = chromadb.utils.embedding_functions.SentenceTransformerEmbeddingFunction(
            model_name=self.embedding_model)
        self.chroma_client = chromadb.HttpClient(host=self.host, port=self.port)

    def list_collections(self):
        """
        A method to list all collections in ChromaDB
        Returns:
            List of collection names
        """
        return self.chroma_client.list_collections()

    def add_specific(self, file_name, sheet_name, collection_name):
        """
        A method for adding specific to ChromaDB collection
        Arguments:
        - file_name: str - A spreadsheet file with specific data.
        - sheet_name: str - Name of a sheet from spreadsheet file.
        - collection_name: str - Name of ChromaDB collection to be created. Must be Latin letters and numbers only.
        """
        spec_data = pd.read_excel(file_name, sheet_name=sheet_name, header=[0,1,2,3])
        spec_data = spec_data.fillna("")
        res = {}
        res['description_full'] = []
        for i in spec_data.columns:
            ii = list(i)
            res['description_full'].append({})
            res['description_full'][-1]['column_title'] = ''
            for j in range(1, len(ii)):
                if not (ii[j].startswith("Unnamed")):
                    res['description_full'][-1]['column_title'] += ii[j]
                    res['description_full'][-1]['column_title'] += '__'
            res['description_full'][-1]['column_title'] = res['description_full'][-1]['column_title'][:-2]
            res['description_full'][-1]['column_text'] = " ".join(spec_data[i].tolist()).strip()
        
        ids = []
        documents = []
        metadatas = []
        for j in range(len(res['description_full'])):
            ids.append("id" + str(j))
            documents.append(res['description_full'][j]['column_text'])
            md = {}
            md['column_title'] = res['description_full'][j]['column_title']
            metadatas.append(deepcopy(md))
        
        # Создаем коллекцию с метаданными о происхождении
        collection_metadata = {
            "source_file": file_name,
            "sheet_name": sheet_name,
            "conf_title": spec_data.columns[0][0],
            "conf_title_short": sheet_name
        }
        
        # Создаем новую коллекцию или получаем существующую
        try:
            # Пробуем получить существующую коллекцию
            collection = self.chroma_client.get_collection(
                name=collection_name, 
                embedding_function=self.embedding_function
            )
            print(f"Collection '{collection_name}' already exists. Adding new documents.")
        except Exception:
            # Если коллекция не существует, создаем новую
            collection = self.chroma_client.create_collection(
                name=collection_name,
                metadata=collection_metadata,
                embedding_function=self.embedding_function
            )
            print(f"Created new collection '{collection_name}'.")
        
        # Добавляем документы в коллекцию
        collection.add(
            metadatas=metadatas,
            documents=documents,
            ids=ids
        )
        print(f"Added {len(documents)} documents to collection '{collection_name}'.")
        
        return collection_name
    
    def get_collection_info(self, collection_name):
        """
        A method to get information about a collection
        Arguments:
        - collection_name: str - A name of ChromaDB collection
        Returns:
            Dictionary with collection information
        """
        try:
            collection = self.chroma_client.get_collection(
                name=collection_name, 
                embedding_function=self.embedding_function
            )
            # Получаем метаданные коллекции
            metadata = collection.metadata
            # Получаем количество документов
            count = collection.count()
            
            return {
                "name": collection_name,
                "document_count": count,
                "metadata": metadata
            }
        except Exception as e:
            print(f"Error getting collection info: {e}")
            return None

    def get_specifics(self, collection_name):
        """
        A method to get collection contents by name
        Arguments:
        - collection_name: str - A name of ChromaDB collection (must be an existing collection)
        """
        collection = self.chroma_client.get_collection(name=collection_name, embedding_function=self.embedding_function)
        return collection.get(include=["documents", "embeddings", "metadatas"])
    
    def find_similar_records(self, collection_name, texts: list, n_results=5):
        """
        A method for searching parts of specifics that could be similar to a given text
        Arguments:
        - collection_name: str - A name of a collection where parts should be searched
        - texts: list - A lists of texts (str) to be found (compared)
        - n_results: int - Number of search results to return (by default 5)
        """
        collection = self.chroma_client.get_collection(name=collection_name, embedding_function=self.embedding_function)
        return collection.query(query_texts=texts, n_results=n_results, include=["documents", "metadatas"])
    
    def delete_collection(self, collection_name):
        """
        A method to delete a collection
        Arguments:
        - collection_name: str - A name of ChromaDB collection to delete
        """
        try:
            self.chroma_client.delete_collection(name=collection_name)
            print(f"Collection '{collection_name}' deleted successfully.")
            return True
        except Exception as e:
            print(f"Error deleting collection: {e}")
            return False

# %% [markdown]
# load data

# %%
specifics_path = "D:/GitHub/Edulytica/src/rag/data/Specification.xlsx"

# %%
cs = ChromaSearcher()
cs.add_specific(specifics_path, "ППС", "PPS")
# Out:
# 2025-04-18 21:55:53.482 | INFO     | rag.core.utils.config_loader:load_config:47 - Configuration loaded successfully: {'count_keywords': 10, 'host': 'localhost', 'port': 8080, 'collections_file': 'all_collections.json', 'embedding_model': 'BAAI/bge-m3'}
# Created new collection 'PPS'.
# Added 8 documents to collection 'PPS'.
# 'PPS'

# %%
cl = cs.get_specifics("PPS")
print(cl)
# Out:
# {'ids': ['id0', 'id1', 'id2', 'id3', 'id4', 'id5', 'id6', 'id7'], 'embeddings': array([[-0.05616511, -0.01541862, -0.02970634, ...,  0.016752  ,
#          0.00894882, -0.00475067],
#        [-0.02731149,  0.00175687, -0.03545567, ...,  0.01454608,
#         -0.05446029, -0.02225705],
#        [-0.0324773 ,  0.01229401, -0.01113146, ..., -0.01004309,
#         -0.05448178, -0.01861655],
#        ...,
#        [-0.03238031,  0.01179582, -0.0283231 , ..., -0.01092045,
#         -0.01374846,  0.01287064],
#        [-0.05800085,  0.01502216, -0.04128072, ..., -0.00755922,
#         -0.03570972, -0.00576454],
#        [-0.01509039,  0.00757372,  0.01312466, ..., -0.02653653,
#         -0.02884256, -0.03378146]]), 'metadatas': [{'column_title': 'О конференции'}, {'column_title': 'Программа конференции'}, {'column_title': 'Секции__Секция 1'}, {'column_title': 'Секции__Секция 2'}, {'column_title': 'Секции__Секция 3'}, {'column_title': 'Секции__Секция 4'}, {'column_title': 'Требования__Требования к статье'}, {'column_title': 'Требования__ТРЕБОВАНИЯ К ОФОРМЛЕНИЮ МАТЕРИАЛА'}], 'documents': ['Конференция направлена на ознакомление научной общественности с итогами реализации научных проектов в рамках инновационной образовательной программы, аналитической ведомственной целевой программы «Развитие научного потенциала высшей школы», научно-технических программ (межвузовских, отраслевых, федеральных), грантов и с результатами научных, научно-технических и учебно-методических достижений по направлениям деятельности университета, достигнутые учеными, преподавателями, научными сотрудниками, аспирантами и студентами, в том числе в содружестве с предприятиями и организациями Санкт-Петербурга.', 'https://disk.yandex.ru/d/FVEYfafGrEmaeQ', 'Итоги реализации научных проектов в рамках государственного задания Министерства науки и высшего образования Российской Федерации за 2024 год.', 'Итоги выполнения НИР с участием магистрантов и аспирантов в 2024 году.', 'Итоги выполнения практико-ориентированных НИОКТР.', 'Итоги реализации научно-технических программ и грантов, выполняемых в 2024 году, и результаты научных, научно-технических и учебно-методических исследований по направлениям деятельности факультетов.', 'ВНИМАНИЕ!\nСтатьи без аннотации, ключевых слов и списка использованных источников не принимаются.\nЗаверенные экземпляры текста статьи должны быть подписаны автором и научным руководителем НАСТОЯЩЕЙ ПОДПИСЬЮ. Подпись ставится в конце статьи с расшифровкой или в начале около фамилий.\n\nУДК \nДалее на первой строчке (выровнять по левому краю – в левом верхнем углу): индекс универсальной десятичной классификации (УДК). Печать УДК вместе с цифрами выполняется прописными буквами. УДК приведены в электронном классификаторе: http://teacode.com/online/udc/\nЧерез интервал с выравниванием по центру прописными буквами приводится название статьи научной работы.\n\nНАЗВАНИЕ СТАТЬИ\n\nС новой строки приводятся фамилия, инициалы автора (студента или аспиранта), соавторы указываются в строчку через запятую. Под ФИО ссылками указываются полные наименования организаций (выравнивание по левому краю, курсив).\nИванов И.И.1 (статус), Петров П.П.2 (статус), Сидорова Е.И.1 (статус)\n1 – Полное название организации\n2 – Полное название организации\nС новой строки приводится степень, звание, инициалы и фамилия научного руководителя, название организации в соответствии с полной редакцией устава, если авторы и руководитель из Университета ИТМО, то название организации не заполняется  (выравнивание по левому краю, курсив).\nНаучный руководитель – степень, звание Смирнова И.И.2\n2 – Полное название организации\nВНИМАНИЕ! Если научный руководитель является также соавтором работы, его необходимо указать дважды: сначала в списке авторов, затем в строке Научный руководитель –.\n\nЧерез интервал с красной строки приводятся контактные e-mail статьи (выравнивание по левому краю, курсив):\ne-mail: pps @itmo.ru\n\nЧерез интервал указывается тема научно-исследовательской работы (НИР), в рамках которой выполнена работа (по выполнению хоздоговорных и госбюджетных НИР, грантов, договоров о содружестве):\nРабота выполнена в рамках темы НИР №620150 «Повышение эффективности энергетических систем путем использования аккумуляторов тепловой энергии».\n\n\nАннотация и ключевые слова отделяются от информации об авторах и основного текста чертами.\nЧерез интервал без абзацного отступа приводятся аннотация статьи (5–6 строк) и ключевые слова. Аннотация и ключевые слова должны иметь: междустрочный интервал 1, шрифт Times New Roman – 11 пт. Ключевых слов должно быть не менее 5.\nАннотация\nВ работе рассмотрено применение псевдозерновой культуры киноа в качестве нетрад ...

# %%
cqq = cs.find_similar_records("PPS", ["Статья должна быть оформлена"])

# %% [markdown]
# ### Refactoring

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '../../'))
sys.path.append(project_root)

# %%
import chromadb
import pandas as pd
from copy import deepcopy
import os
from typing import List, Dict, Any, Optional, Union, Tuple
from loguru import logger
from rag.core.utils.config_loader import ConfigLoader

# %%
class EmbeddingProcessor:
    """
    Класс для создания и обработки эмбеддингов из текстовых данных
    """
    def __init__(self, embedding_model: Optional[str] = None):
        """
        Инициализация с выбором модели эмбеддингов
        
        Args:
            embedding_model: Название модели для создания эмбеддингов (опционально)
                            Если не указана, будет использована модель из конфигурации
        """
        config_loader = ConfigLoader()
        self.embedding_model = embedding_model or config_loader.get_embedding_model()
        logger.info(f"Initializing EmbeddingProcessor with model: {self.embedding_model}")
        
        try:
            self.embedding_function = chromadb.utils.embedding_functions.SentenceTransformerEmbeddingFunction(
                model_name=self.embedding_model)
            logger.info(f"Successfully initialized embedding function with model {self.embedding_model}")
        except Exception as e:
            logger.error(f"Failed to initialize embedding function: {e}")
            raise
    
    def get_embedding_function(self):
        """
        Получить функцию для создания эмбеддингов
        
        Returns:
            Функция для создания эмбеддингов
        """
        return self.embedding_function
    
    def process_excel_data(self, file_name: str, sheet_name: str) -> Dict[str, Any]:
        """
        Обработка Excel-файла и подготовка данных для эмбеддингов
        
        Args:
            file_name: Путь к Excel-файлу
            sheet_name: Имя листа в Excel-файле
            
        Returns:
            Словарь со структурированными данными для сохранения в ChromaDB
        """
        logger.info(f"Processing Excel data from file: {file_name}, sheet: {sheet_name}")
        
        try:
            # Чтение данных из Excel
            spec_data = pd.read_excel(file_name, sheet_name=sheet_name, header=[0,1,2,3])
            spec_data = spec_data.fillna("")
            logger.info(f"Successfully read Excel data with shape: {spec_data.shape}")
            
            # Обработка данных
            res = {}
            res['description_full'] = []
            
            # Обрабатываем заголовки столбцов
            for i in spec_data.columns:
                ii = list(i)
                res['description_full'].append({})
                res['description_full'][-1]['column_title'] = ''
                
                for j in range(1, len(ii)):
                    if not (ii[j].startswith("Unnamed")):
                        res['description_full'][-1]['column_title'] += ii[j]
                        res['description_full'][-1]['column_title'] += '__'
                
                res['description_full'][-1]['column_title'] = res['description_full'][-1]['column_title'][:-2]
                res['description_full'][-1]['column_text'] = " ".join(spec_data[i].tolist()).strip()
            
            # Готовим данные для ChromaDB
            ids = []
            documents = []
            metadatas = []
            
            for j in range(len(res['description_full'])):
                ids.append(f"id{j}")
                documents.append(res['description_full'][j]['column_text'])
                md = {
                    'column_title': res['description_full'][j]['column_title']
                }
                metadatas.append(deepcopy(md))
            
            # Создаем метаданные коллекции
            collection_metadata = {
                "source_file": file_name,
                "sheet_name": sheet_name,
                "conf_title": spec_data.columns[0][0],
                "conf_title_short": sheet_name
            }
            
            logger.info(f"Processed {len(documents)} documents from Excel data")
            
            return {
                "ids": ids,
                "documents": documents,
                "metadatas": metadatas,
                "collection_metadata": collection_metadata
            }
            
        except Exception as e:
            logger.error(f"Error processing Excel data: {e}")
            raise

# %%
class ChromaDBManager:
    """
    Класс для управления коллекциями в ChromaDB
    """
    def __init__(self, embedding_function=None):
        """
        Инициализация менеджера ChromaDB и установление соединения
        
        Args:
            embedding_function: функция для создания эмбеддингов (опционально)
                              Если не указана, будет использована модель из конфигурации
        """
        config_loader = ConfigLoader()
        config = config_loader.load_config()
        self.host = config_loader.get_host()
        self.port = config_loader.get_port()
        
        logger.info(f"Initializing ChromaDBManager with host: {self.host}, port: {self.port}")
        
        # Устанавливаем соединение с ChromaDB
        try:
            self.chroma_client = chromadb.HttpClient(host=self.host, port=self.port)
            logger.info("Successfully connected to ChromaDB")
        except Exception as e:
            logger.error(f"Failed to connect to ChromaDB: {e}")
            raise
        
        # Используем переданную функцию эмбеддингов или создаем новую из конфигурации
        if embedding_function:
            self.embedding_function = embedding_function
            logger.info("Using provided embedding function")
        else:
            try:
                embedding_model = config_loader.get_embedding_model()
                self.embedding_function = chromadb.utils.embedding_functions.SentenceTransformerEmbeddingFunction(
                    model_name=embedding_model)
                logger.info(f"Created embedding function with model: {embedding_model}")
            except Exception as e:
                logger.error(f"Failed to create embedding function: {e}")
                raise
    
    def list_collections(self) -> List[Dict[str, Any]]:
        """
        Получить список всех коллекций в ChromaDB
        
        Returns:
            Список коллекций с их метаданными
        """
        try:
            collections = self.chroma_client.list_collections()
            logger.info(f"Listed {len(collections)} collections in ChromaDB")
            return collections
        except Exception as e:
            logger.error(f"Error listing collections: {e}")
            return []
    
    def create_collection(self, name: str, metadata: Optional[Dict[str, Any]] = None) -> Any:
        """
        Создать новую коллекцию
        
        Args:
            name: Имя коллекции
            metadata: Метаданные коллекции (опционально)
            
        Returns:
            Объект коллекции
        """
        try:
            # Пробуем получить существующую коллекцию
            collection = self.chroma_client.get_collection(
                name=name, 
                embedding_function=self.embedding_function
            )
            logger.info(f"Collection '{name}' already exists.")
        except Exception:
            # Если коллекция не существует, создаем новую
            collection = self.chroma_client.create_collection(
                name=name,
                metadata=metadata,
                embedding_function=self.embedding_function
            )
            logger.info(f"Created new collection '{name}' with metadata: {metadata}")
        
        return collection
    
    def get_collection(self, name: str) -> Any:
        """
        Получить коллекцию по имени
        
        Args:
            name: Имя коллекции
            
        Returns:
            Объект коллекции или None, если коллекция не найдена
        """
        try:
            collection = self.chroma_client.get_collection(
                name=name, 
                embedding_function=self.embedding_function
            )
            logger.info(f"Retrieved collection '{name}'")
            return collection
        except Exception as e:
            logger.error(f"Error getting collection '{name}': {e}")
            return None
    
   
    
    def add_documents(self, 
                     collection_name: str, 
                     documents: List[str], 
                     metadatas: Optional[List[Dict[str, Any]]] = None, 
                     ids: Optional[List[str]] = None) -> bool:
        """
        Добавить документы в коллекцию
        
        Args:
            collection_name: Имя коллекции
            documents: Список текстов документов
            metadatas: Список метаданных для каждого документа (опционально)
            ids: Список идентификаторов для каждого документа (опционально)
            
        Returns:
            True, если документы успешно добавлены, иначе False
        """
        try:
            collection = self.get_collection(collection_name)
            if not collection:
                logger.error(f"Collection '{collection_name}' not found")
                return False
            
            # Генерируем идентификаторы, если они не предоставлены
            if not ids:
                ids = [f"id{i}" for i in range(len(documents))]
            
            # Добавляем документы в коллекцию
            collection.add(
                documents=documents,
                metadatas=metadatas,
                ids=ids
            )
            
            logger.info(f"Added {len(documents)} documents to collection '{collection_name}'")
            return True
        except Exception as e:
            logger.error(f"Error adding documents to collection '{collection_name}': {e}")
            return False
    

    
    def get_collection_contents(self, 
                              collection_name: str, 
                              include: Optional[List[str]] = None) -> Dict[str, Any]:
        """
        Получить все содержимое коллекции
        
        Args:
            collection_name: Имя коллекции
            include: Что включать в результаты ("documents", "metadatas", "embeddings")
            
        Returns:
            Содержимое коллекции или пустой словарь в случае ошибки
        """
        try:
            collection = self.get_collection(collection_name)
            if not collection:
                logger.error(f"Collection '{collection_name}' not found")
                return {}
            
            # Устанавливаем, что включать в результаты по умолчанию
            if include is None:
                include = ["documents", "metadatas"]
            
            # Получаем все содержимое коллекции
            contents = collection.get(include=include)
            
            logger.info(f"Got contents for collection '{collection_name}': {len(contents.get('ids', []))} documents")
            return contents
        except Exception as e:
            logger.error(f"Error getting collection contents for '{collection_name}': {e}")
            return {}
    

    
    def add_from_excel(self, file_name: str, sheet_name: str, collection_name: str) -> bool:
        """
        Добавить данные из Excel-файла в коллекцию ChromaDB
        
        Args:
            file_name: Путь к Excel-файлу
            sheet_name: Имя листа в Excel-файле
            collection_name: Имя коллекции для создания/обновления
            
        Returns:
            True, если данные успешно добавлены, иначе False
        """
        try:
            # Создаем процессор эмбеддингов для обработки данных
            processor = EmbeddingProcessor()
            
            # Обрабатываем данные из Excel
            data = processor.process_excel_data(file_name, sheet_name)
            
            # Создаем или получаем коллекцию
            self.create_collection(
                name=collection_name, 
                metadata=data["collection_metadata"]
            )
            
            # Добавляем документы в коллекцию
            success = self.add_documents(
                collection_name=collection_name,
                documents=data["documents"],
                metadatas=data["metadatas"],
                ids=data["ids"]
            )
            
            if success:
                logger.info(f"Successfully added data from {file_name} ({sheet_name}) to collection '{collection_name}'")
            else:
                logger.error(f"Failed to add data from {file_name} to collection '{collection_name}'")
            
            return success
        except Exception as e:
            logger.error(f"Error adding data from Excel to collection: {e}")
            return False
        
        
    def delete_all_collections(self) -> Dict[str, Any]:
        """
        Удалить все коллекции в ChromaDB
        
        Returns:
            Словарь с информацией о результатах удаления:
            {
                "success": bool - общий успех операции,
                "total": int - общее количество коллекций,
                "deleted": int - количество успешно удаленных коллекций,
                "failed": int - количество коллекций, которые не удалось удалить,
                "failed_collections": List[str] - имена коллекций, которые не удалось удалить
            }
        """
        try:
            # Получаем список всех коллекций
            collections = self.list_collections()
            
            if not collections:
                logger.info("No collections found to delete")
                return {
                    "success": True,
                    "total": 0,
                    "deleted": 0,
                    "failed": 0,
                    "failed_collections": []
                }
            
            # Счетчики для отслеживания прогресса
            deleted_count = 0
            failed_count = 0
            failed_collections = []
            
            # Удаляем каждую коллекцию
            for collection in collections:
                collection_name = collection.name
                try:
                    self.chroma_client.delete_collection(name=collection_name)
                    deleted_count += 1
                    logger.info(f"Deleted collection '{collection_name}'")
                except Exception as e:
                    failed_count += 1
                    failed_collections.append(collection_name)
                    logger.error(f"Failed to delete collection '{collection_name}': {e}")
            
            # Определяем общий успех операции
            success = failed_count == 0
            
            # Результат операции
            result = {
                "success": success,
                "total": len(collections),
                "deleted": deleted_count,
                "failed": failed_count,
                "failed_collections": failed_collections
            }
            
            logger.info(f"Delete all collections operation completed: {deleted_count} deleted, {failed_count} failed")
            return result
            
        except Exception as e:
            logger.error(f"Error in delete_all_collections: {e}")
            return {
                "success": False,
                "total": 0,
                "deleted": 0,
                "failed": 0,
                "failed_collections": [],
                "error": str(e)
            }

# %%
# Создаем экземпляр ChromaDBManager
chroma_manager = ChromaDBManager()

# Получаем список всех коллекций
collections = chroma_manager.list_collections()

# Выводим только имена коллекций
collection_names = [collection.name for collection in collections]
print(f"Найдено {len(collection_names)} коллекций:")
print(", ".join(collection_names))
# Out:
# 2025-04-21 18:36:28.689 | INFO     | rag.core.utils.config_loader:load_config:47 - Configuration loaded successfully: {'count_keywords': 10, 'host': 'localhost', 'port': 8080, 'collections_file': 'all_collections.json', 'embedding_model': 'BAAI/bge-m3'}
# 2025-04-21 18:36:28.690 | INFO     | __main__:__init__:18 - Initializing ChromaDBManager with host: localhost, port: 8080
# 2025-04-21 18:36:29.162 | INFO     | __main__:__init__:23 - Successfully connected to ChromaDB
# 2025-04-21 18:36:48.427 | INFO     | __main__:__init__:37 - Created embedding function with model: BAAI/bge-m3
# 2025-04-21 18:36:48.433 | INFO     | __main__:list_collections:51 - Listed 5 collections in ChromaDB
# Найдено 5 коллекций:
# KMU, FRUCT, EPI, YSC, PPS

# %%
# Удаляем все коллекции
#result = chroma_manager.delete_all_collections()
# Out:
# 2025-04-18 22:19:53.492 | INFO     | __main__:list_collections:51 - Listed 1 collections in ChromaDB
# 2025-04-18 22:19:53.507 | INFO     | __main__:delete_all_collections:268 - Deleted collection 'PPS'
# 2025-04-18 22:19:53.508 | INFO     | __main__:delete_all_collections:286 - Delete all collections operation completed: 1 deleted, 0 failed

# %%
# Добавляем данные из Excel в коллекцию
# specifics_path = "D:/GitHub/Edulytica/src/rag/data/Specification.xlsx"
# chroma_manager.add_from_excel(specifics_path, "ППС", "PPS")
# chroma_manager.add_from_excel(specifics_path, "КМУ", "KMU")
# chroma_manager.add_from_excel(specifics_path, "ЭПИ", "EPI")
# chroma_manager.add_from_excel(specifics_path, "YSC", "YSC")
# chroma_manager.add_from_excel(specifics_path, "FRUCT", "FRUCT")
# Out:
# 2025-04-18 22:22:17.948 | INFO     | rag.core.utils.config_loader:load_config:47 - Configuration loaded successfully: {'count_keywords': 10, 'host': 'localhost', 'port': 8080, 'collections_file': 'all_collections.json', 'embedding_model': 'BAAI/bge-m3'}
# 2025-04-18 22:22:17.948 | INFO     | __main__:__init__:15 - Initializing EmbeddingProcessor with model: BAAI/bge-m3
# 2025-04-18 22:22:17.948 | INFO     | __main__:__init__:20 - Successfully initialized embedding function with model BAAI/bge-m3
# 2025-04-18 22:22:17.949 | INFO     | __main__:process_excel_data:45 - Processing Excel data from file: D:/GitHub/Edulytica/src/rag/data/Specification.xlsx, sheet: ППС
# 2025-04-18 22:22:17.963 | INFO     | __main__:process_excel_data:51 - Successfully read Excel data with shape: (1, 8)
# 2025-04-18 22:22:17.963 | INFO     | __main__:process_excel_data:92 - Processed 8 documents from Excel data
# 2025-04-18 22:22:18.019 | INFO     | __main__:create_collection:82 - Created new collection 'PPS' with metadata: {'source_file': 'D:/GitHub/Edulytica/src/rag/data/Specification.xlsx', 'sheet_name': 'ППС', 'conf_title': 'Научная и учебно-методическая конференция Университета ИТМО (ППС)', 'conf_title_short': 'ППС'}
# 2025-04-18 22:22:18.020 | INFO     | __main__:get_collection:101 - Retrieved collection 'PPS'
# 2025-04-18 22:22:54.396 | INFO     | __main__:add_documents:143 - Added 8 documents to collection 'PPS'
# 2025-04-18 22:22:54.396 | INFO     | __main__:add_from_excel:219 - Successfully added data from D:/GitHub/Edulytica/src/rag/data/Specification.xlsx (ППС) to collection 'PPS'
# 2025-04-18 22:22:54.398 | INFO     | rag.core.utils.config_loader:load_config:47 - Configuration loaded successfully: {'count_keywords': 10, 'host': 'localhost', 'port': 8080, 'collections_file': 'all_collections.json', 'embedding_model': 'BAAI/bge-m3'}
# 2025-04-18 22:22:54.398 | INFO     | __main__:__init__:15 - Initializing EmbeddingProcessor with model: BAAI/bge-m3
# 2025-04-18 22:22:54.398 | INFO     | __main__:__init__:20 - Successfully initialized embedding function with model BAAI/bge-m3
# 2025-04-18 22:22:54.398 | INFO     | __main__:process_excel_data:45 - Processing Excel data from file: D:/GitHub/Edulytica/src/rag/data/Specification.xlsx, sheet: КМУ
# 2025-04-18 22:22:54.422 | INFO     | __main__:process_excel_data:51 - Successfully read Excel data with shape: (1, 192)
# 2025-04-18 22:22:54.430 | INFO     | __main__:process_excel_data:92 - Processed 192 documents from Excel data
# 2025-04-18 22:22:54.485 | INFO     | __main__:create_collection:82 - Created new collection 'KMU' with metadata: {'source_file': 'D:/GitHub/Edulytica/src/rag/data/Specification.xlsx', 'sheet_name': 'КМУ', 'conf_title': 'Конгресс молодых ученых Университета ИТМО', 'conf_title_short': 'КМУ'}
# 2025-04-18 22:22:54.488 | INFO     | __main__:get_collection:101 - Retrieved collection 'KMU'
# 2025-04-18 22:23:13.979 | INFO     | __main__:add_documents:143 - Added 192 documents to collection 'KMU'
# 2025-04-18 22:23:13.979 | INFO     | __main__:add_from_excel:219 - Successfully added data from D:/GitHub/Edulytica/src/rag/data/Specification.xlsx (КМУ) to collection 'KMU'
# 2025-04-18 22:23:13.981 | INFO     | rag.core.utils.config_loader:load_config:47 - Configuration loaded successfully: {'count_keywords': 10, 'host': 'localhost', 'port': 8080, 'collections_file': 'all_collections.json', 'embedding_model': 'BAAI/bge-m3'}
# 2025-04-18 22:23:13.981 | INFO     | __main__:__init__:15 - Initializing EmbeddingProcessor with model: BAAI/bge-m3
# 2025-04-18 22:23:13.982 | INFO     | __main__:__init__:20 - Successfully initialized embedding function with model BAAI/bge-m3
# 2025-04-18 22:23:13.982 | INFO     | __main__:process_excel_data:45 - Processing Excel data from file: D:/GitHub/Edulytica/src/rag/data/Specification.xlsx, sheet: ЭПИ
# 2025-04-18 22:23:13.994 | INFO     | __main__:process_excel_data:51 - Successfully read Excel data with shape: (1, 23)
# 2025-04-18 22:23:13.997 | INFO     | __main__:process_excel_data:92 - Processed 23 documents from Excel data
# 2025-04-18 22:23:14.055 | INFO     | __main__:create_collection:82 - Created new collection 'EPI' with metadata: {'source_file': 'D:/GitHub/Edulytica/src/rag/data/Specification.xlsx', 'sheet_name': 'ЭПИ', 'conf_title': 'Экономика, право и инновации', 'conf_title_short': 'ЭПИ'}
# 2025-04-18 22:23:14.057 | INFO     | __main__:get_collection:101 - Retrieved collection 'EPI'
# 2025-04-18 22:23:33.816 | INFO     | __main__:add_documents:143 - Added 23 documents to collection 'EPI'
# 2025-04-18 22:23:33.818 | INFO     | __main__:add_from_excel:219 - Successfully added data from D:/GitHub/Edulytica/src/rag/data/Specification.xlsx (ЭПИ) to collection 'EPI'
# 2025-04-18 22:23:33.819 | INFO     | rag.core.utils.config_loader:load_config:47 - Configuration loaded successfully: {'count_keywords': 10, 'host': 'localhost', 'port': 8080, 'collections_file': 'all_collections.json', 'embedding_model': 'BAAI/bge-m3'}
# 2025-04-18 22:23:33.819 | INFO     | __main__:__init__:15 - Initializing EmbeddingProcessor with model: BAAI/bge-m3
# 2025-04-18 22:23:33.819 | INFO     | __main__:__init__:20 - Successfully initialized embedding function with model BAAI/bge-m3
# 2025-04-18 22:23:33.819 | INFO     | __main__:process_excel_data:45 - Processing Excel data from file: D:/GitHub/Edulytica/src/rag/data/Specification.xlsx, sheet: YSC
# 2025-04-18 22:23:33.834 | INFO     | __main__:process_excel_data:51 - Successfully read Excel data with shape: (1, 30)
# 2025-04-18 22:23:33.835 | INFO     | __main__:process_excel_data:92 - Processed 30 documents from Excel data
# 2025-04-18 22:23:33.895 | INFO     | __main__:create_collection:82 - Created new collection 'YSC' with metadata: {'source_file': 'D:/GitHub/Edulytica/src/rag/data/Specification.xlsx', 'sheet_name': 'YSC', 'conf_title': 'Young Scientists Conference on Computational Sciences', 'conf_title_short': 'YSC'}
# 2025-04-18 22:23:33.895 | INFO     | __main__:get_collection:101 - Retrieved collection 'YSC'
# 2025-04-18 22:24:55.964 | INFO     | __main__:add_documents:143 - Added 30 documents to collection 'YSC'
# 2025-04-18 22:24:55.964 | INFO     | __main__:add_from_excel:219 - Successfully added data from D:/GitHub/Edulytica/src/rag/data/Specification.xlsx (YSC) to collection 'YSC'
# 2025-04-18 22:24:55.966 | INFO     | rag.core.utils.config_loader:load_config:47 - Configuration loaded successfully: {'count_keywords': 10, 'host': 'localhost', 'port': 8080, 'collections_file': 'all_collections.json', 'embedding_model': 'BAAI/bge-m3'}
# 2025-04-18 22:24:55.966 | INFO     | __main__:__init__:15 - Initializing EmbeddingProcessor with model: BAAI/bge-m3
# 2025-04-18 22:24:55.967 | INFO     | __main__:__init__:20 - Successfully initialized embedding function with model BAAI/bge-m3
# 2025-04-18 22:24:55.967 | INFO     | __main__:process_excel_data:45 - Processing Excel data from file: D:/GitHub/Edulytica/src/rag/data/Specification.xlsx, sheet: FRUCT
# 2025-04-18 22:24:55.980 | INFO     | __main__:process_excel_data:51 - Successfully read Excel data with shape: (1, 3)
# 2025-04-18 22:24:55.980 | INFO     | __main__:process_excel_data:92 - Processed 3 documents from Excel data
# 2025-04-18 22:24:56.040 | INFO     | __main__:create_collection:82 - Created new collection 'FRUCT' with metadata: {'source_file': 'D:/GitHub/Edulytica/src/rag/data/Specification.xlsx', 'sheet_name': 'FRUCT', 'conf_title': 'FRUCT', 'conf_title_short': 'FRUCT'}
# 2025-04-18 22:24:56.042 | INFO     | __main__:get_collection:101 - Retrieved collection 'FRUCT'
# 2025-04-18 22:24:56.712 | INFO     | __main__:add_documents:143 - Added 3 documents to collection 'FRUCT'
# 2025-04-18 22:24:56.712 | INFO     | __main__:add_from_excel:219 - Successfully added data from D:/GitHub/Edulytica/src/rag/data/Specification.xlsx (FRUCT) to collection 'FRUCT'
# True

# %% [markdown]
# ### Get data

# %%
# Получаем все содержимое коллекции "PPS"
kmu_data = chroma_manager.get_collection_contents(
    collection_name="KMU",
    include=["documents", "embeddings", "metadatas"]
)
kmu_data
# Out:
# 2025-04-18 23:16:48.690 | INFO     | __main__:get_collection:101 - Retrieved collection 'KMU'
# 2025-04-18 23:16:48.765 | INFO     | __main__:get_collection_contents:177 - Got contents for collection 'KMU': 192 documents
# {'ids': ['id0',
#   'id1',
#   'id2',
#   'id3',
#   'id4',
#   'id5',
#   'id6',
#   'id7',
#   'id8',
#   'id9',
#   'id10',
#   'id11',
#   'id12',
#   'id13',
#   'id14',
#   'id15',
#   'id16',
#   'id17',
#   'id18',
#   'id19',
#   'id20',
#   'id21',
#   'id22',
#   'id23',
#   'id24',
#   'id25',
#   'id26',
#   'id27',
#   'id28',
#   'id29',
#   'id30',
#   'id31',
#   'id32',
#   'id33',
#   'id34',
#   'id35',
#   'id36',
#   'id37',
#   'id38',
#   'id39',
#   'id40',
#   'id41',
#   'id42',
#   'id43',
#   'id44',
#   'id45',
#   'id46',
#   'id47',
#   'id48',
#   'id49',
#   'id50',
#   'id51',
#   'id52',
#   'id53',
#   'id54',
#   'id55',
#   'id56',
#   'id57',
#   'id58',
#   'id59',
#   'id60',
#   'id61',
#   'id62',
#   'id63',
#   'id64',
#   'id65',
#   'id66',
#   'id67',
#   'id68',
#   'id69',
#   'id70',
#   'id71',
#   'id72',
#   'id73',
#   'id74',
#   'id75',
#   'id76',
#   'id77',
#   'id78',
#   'id79',
#   'id80',
#   'id81',
#   'id82',
#   'id83',
#   'id84',
#   'id85',
#   'id86',
#   'id87',
#   'id88',
#   'id89',
#   'id90',
#   'id91',
#   'id92',
#   'id93',
#   'id94',
#   'id95',
#   'id96',
#   'id97',
#   'id98',
#   'id99',
#   'id100',
#   'id101',
#   'id102',
#   'id103',
#   'id104',
#   'id105',
#   'id106',
#   'id107',
#   'id108',
#   'id109',
#   'id110',
#   'id111',
#   'id112',
#   'id113',
#   'id114',
#   'id115',
#   'id116',
#   'id117',
#   'id118',
#   'id119',
#   'id120',
#   'id121',
#   'id122',
#   'id123',
#   'id124',
#   'id125',
#   'id126',
#   'id127',
#   'id128',
#   'id129',
#   'id130',
#   'id131',
#   'id132',
#   'id133',
#   'id134',
#   'id135',
#   'id136',
#   'id137',
#   'id138',
#   'id139',
#   'id140',
#   'id141',
#   'id142',
#   'id143',
#   'id144',
#   'id145',
#   'id146',
#   'id147',
#   'id148',
#   'id149',
#   'id150',
#   'id151',
#   'id152',
#   'id153',
#   'id154',
#   'id155',
#   'id156',
#   'id157',
#   'id158',
#   'id159',
#   'id160',
#   'id161',
#   'id162',
#   'id163',
#   'id164',
#   'id165',
#   'id166',
#   'id167',
#   'id168',
#   'id169',
#   'id170',
#   'id171',
#   'id172',
#   'id173',
#   'id174',
#   'id175',
#   'id176',
#   'id177',
#   'id178',
#   'id179',
#   'id180',
#   'id181',
#   'id182',
#   'id183',
#   'id184',
#   'id185',
#   'id186',
#   'id187',
#   'id188',
#   'id189',
#   'id190',
#   'id191'],
#  'embeddings': array([[-2.7076216e-02, -1.1813105e-02, -1.6232446e-02, ...,
#          -1.1040311e-03,  3.8095910e-03,  1.1542971e-02],
#         [-3.0360835e-02, -1.7074877e-02,  5.1413146e-03, ...,
#           6.4832163e-03, -6.0067162e-02,  7.0050250e-05],
#         [-6.0118890e-02, -6.7907680e-03, -1.9777752e-02, ...,
#          -2.2478630e-02,  4.9224077e-03, -3.3063922e-02],
#         ...,
#         [-6.2079772e-02, -2.9564345e-02, -2.7737516e-04, ...,
#           4.5525044e-02,  8.2810630e-03, -2.3705393e-02],
#         [-1.7039381e-02,  2.7348245e-02, -1.0289880e-02, ...,
#           1.9056291e-03,  1.2534255e-02, -4.1933300e-02],
#         [-4.5102140e-02,  1.2709593e-02, -9.0211460e-04, ...,
#           2.3117565e-02, -2.1826426e-02,  3.0731732e-02]]),
#  'metadatas': [{'column_title': 'Участие'},
#   {'column_title': 'Результаты'},
#   {'column_title': 'Цель'},
#   {'column_title': 'Положение'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Интеллектуальная собственность и управление инновациями'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Интеллектуальная собственность и управление инновациями.1'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Интеллектуальная собственность и управление инновациями.2'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Актуальные практики бизнес-трансформации: технологические и управленческие аспекты'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Актуальные практики бизнес-трансформации: технологические и управленческие аспекты.1'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Актуальные практики бизнес-трансформации: технологические и управленческие аспекты.2'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Русский язык в многонациональном мире'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Русский язык в многонациональном мире.1'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Русский язык в многонациональном мире.2'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__ОБЩЕСТВО И ЦИФРОВОЕ НЕРАВЕНСТВО: Цифровые исследования в бизнесе и экономике / SOCIETY AND DIGITAL DIVIDE: Digital studies in Business and Economics'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__ОБЩЕСТВО И ЦИФРОВОЕ НЕРАВЕНСТВО: Цифровые исследования в бизнесе и экономике / SOCIETY AND DIGITAL DIVIDE: Digital studies in Business and Economics.1'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__ОБЩЕСТВО И ЦИФРОВОЕ НЕРАВЕНСТВО: Цифровые исследования в бизнесе и экономике / SOCIETY AND DIGITAL DIVIDE: Digital studies in Business and Economics.2'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__ФИРМЫ И РЫНКИ: IT-решения для бизнеса / FIRM AND MARKETS: IT-driven solutions'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__ФИРМЫ И РЫНКИ: IT-решения для бизнеса / FIRM AND MARKETS: IT-driven solutions.1'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__ФИРМЫ И РЫНКИ: IT-решения для бизнеса / FIRM AND MARKETS: IT-driven solutions.2'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Школьная секция «Исследования в области технологического менеджмента и управления инновациями / Technology and innovation management studies»'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Школьная секция «Исследования в области технологического менеджмента и управления инновациями / Technology and innovation management studies».1'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Школьная секция «Исследования в области технологического менеджмента и управления инновациями / Technology and innovation management studies».2'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__УЛУЧШЕНИЕ ЧЕЛОВЕКА И ИИ: Синергия технологий и человеческого потенциала / HUMAN ENHANCEMENT AND AI: The synergy of technology and human potential'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__УЛУЧШЕНИЕ ЧЕЛОВЕКА И ИИ: Синергия технологий и человеческого потенциала / HUMAN ENHANCEMENT AND AI: The synergy of technology and human potential.1'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__УЛУЧШЕНИЕ ЧЕЛОВЕКА И ИИ: Синергия технологий и человеческого потенциала / HUMAN ENHANCEMENT AND AI: The synergy of technology and human potential.2'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Инклюзивный мир вокруг нас: ассистивные разработки, доступные здания и общественные пространства для людей с инвалидностью'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Инклюзивный мир вокруг нас: ассистивные разработки, доступные здания и общественные пространства для людей с инвалидностью.1'},
#   {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__Инклюзивный мир вокруг нас: ассистивные разработки, доступные здания и общественные пространства для людей с инвалидностью.2'},
#   {'column_title': 'Секции__Информационные технологии__Информатика и программирование'},
#   {'column_title': 'Секции__Информационные технологии__Информатика и программирование.1'},
#   {'column_title': 'Секции__Информационные технологии__Информатика и программирование.2'},
#   {'column_title': 'Секции__Информационные технологии__Биоинформатика'},
#   {'column_title': 'Секции__Информационные технологии__Биоинформатика.1'},
#   {'column_title': 'Секции__Информационные технологии__Биоинформатика.2'},
#   {'column_title': 'Секции__Информационные технологии__Информационная безопасность, проектирование, технология элементов и узлов компьютерных систем'},
#   {'column_title': 'Секции__Информационные технологии__Информационная безопасность, проектирование, технология элементов и узлов компьютерных систем.1'},
#   {'column_title': 'Секции__Информационные технологии__Информационная безопасность, проектирование, технология элементов и узлов компьютерных систем.2'},
#   {'column_title': 'Секции__Информационные технологии__Компьютерная графика, цифровой дизайн и интерфейсы'},
#   {'column_title': 'Секции__Информационные технологии__Компьютерная графика, цифровой дизайн и интерфейсы.1'},
#   {'column_title': 'Секции__Информационные технологии__Компьютерная графика, цифровой дизайн и интерфейсы.2'},
#   {'column_title': 'Секции__Информационные технологии__Интеллектуальные инфокоммуникационные технологии'},
#   {'column_title': 'Секции__Информационные технологии__Интеллектуальные инфокоммуникационные технологии.1'},
#   {'column_title': 'Секции__Информационные технологии__Интеллектуальные инфокоммуникационные технологии.2'},
#   {'column_title': 'Секции__Информационные технологии__Математическое моделирование'},
#   {'column_title': 'Секции__Информационные технологии__Математическое моделирование.1'},
#   {'column_title': 'Секции__Информационные технологии__Математическое моделирование.2'},
#   {'column_title': 'Секции__Информационные технологии__Мобильная разработка'},
#   {'column_title': 'Секции__Информационные технологии__Мобильная разработка.1'},
#   {'column_title': 'Секции__Информационные технологии__Мобильная разработка.2'},
#   {'column_title': 'Секции__Информационные технологии__Системы управления и электроинженерия'},
#   {'column_title': 'Секции__Информационные технологии__Системы управления и электроинженерия.1'},
#   {'column_title': 'Секции__Информационные технологии__Цифровые технологии в производстве'},
#   {'column_title': 'Секции__Информационные технологии__Цифровые технологии в производстве.1'},
#   {'column_title': 'Секции__Информационные технологии__Робототехника и искусственный интеллект'},
#   {'column_title': 'Секции__Информационные технологии__Робототехника и искусственный интеллект.1'},
#   {'column_title': 'Секции__Информационные технологии__Инновационные технологии и методы в разработке видеоигр'},
#   {'column_title': 'Секции__Информационные технологии__Инновационные технологии и методы в разработке видеоигр.1'},
#   {'column_title': 'Секции__Информационные технологии__Инновационные технологии и методы в разработке видеоигр.2'},
#   {'column_title': 'Секции__Информационные технологии__Нейротехнологии и программная инженерия'},
#   {'column_title': 'Секции__Информационные технологии__Нейротехнологии и программная инженерия.1'},
#   {'column_title': 'Секции__Информационные технологии__Нейротехнологии и программная инженерия.2'},
#   {'column_title': 'Секции__Информационные технологии__Программная инженерия и технологии'},
#   {'column_title': 'Секции__Информационные технологии__Программная инженерия и технологии.1'},
#   {'column_title': 'Секции__Информационные технологии__Программная инженерия и технологии.2'},
#   {'column_title': 'Секции__Информационные технологии__Речевые и биометрические технологии'},
#   {'column_title': 'Секции__Информационные технологии__Речевые и биометрические технологии.1'},
#   {'column_title': 'Секции__Информационные технологии__Веб-технологии'},
#   {'column_title': 'Секции__Информационные технологии__Веб-технологии.1'},
#   {'column_title': 'Секции__Информационные технологии__Веб-технологии.2'},
#   {'column_title': 'Секции__Искусственный интеллект__Цифровая урбанистика'},
#   {'column_title': 'Секции__Искусственный интеллект__Цифровая урбанистика.1'},
#   {'column_title': 'Секции__Искусственный интеллект__Цифровая урбанистика.2'},
#   {'column_title': 'Секции__Искусственный интеллект__Фундаментальные и прикладные проблемы машинного обучения'},
#   {'column_title': 'Секции__Искусственный интеллект__Фундаментальные и прикладные проблемы машинного обучения.1'},
#   {'column_title': 'Секции__Искусственный интеллект__Фундаментальные и прикладные проблемы машинного обучения.2'},
#   {'column_title': 'Секции__Искусственный интеллект__Искусственный интеллект для безопасности. Безопасность искусственного интеллекта'},
#   {'column_title': 'Секции__Искусственный интеллект__Искусственный интеллект для безопасности. Безопасность искусственного интеллекта.1'},
#   {'column_title': 'Секции__Искусственный интеллект__Искусственный интеллект для безопасности. Безопасность искусственного интеллекта.2'},
#   {'column_title': 'Секции__Искусственный интеллект__Аналитика данных'},
#   {'column_title': 'Секции__Искусственный интеллект__Аналитика данных.1'},
#   {'column_title': 'Секции__Искусственный интеллект__Аналитика данных.2'},
#   {'column_title': 'Секции__Искусственный интеллект__Речевые и биометрические технологии'},
#   {'column_title': 'Секции__Искусственный интеллект__Речевые и биометрические технологии.1'},
#   {'column_title': 'Секции__Искусственный интеллект__Речевые и биометрические технологии.2'},
#   {'column_title': 'Секции__Искусственный интеллект__Технологии искусственного интеллекта'},
#   {'column_title': 'Секции__Искусственный интеллект__Технологии искусственного интеллекта.1'},
#   {'column_title': 'Секции__Искусственный интеллект__Технологии искусственного интеллекта.2'},
#   {'column_title': 'Секции__Искусственный интеллект__Scientific Open-Source Meetup: Открытый код для ИИ'},
#   {'column_title': 'Секции__Искусственный интеллект__Scientific Open-Source Meetup: Открытый код для ИИ.1'},
#   {'column_title': 'Секции__Искусственный интеллект__Scientific Open-Source Meetup: Открытый код для ИИ.2'},
#   {'column_title': 'Секции__Искусственный интеллект__Школьная секция "Инженерия искусственного интеллекта"'},
#   {'column_title': 'Секции__Искусственный интеллект__Школьная секция "Инженерия искусственного интеллекта".1'},
#   {'column_title': 'Секции__Искусственный интеллект__Школьная секция "Инженерия искусственного интеллекта".2'},
#   {'column_title': 'Секции__Искусственный интеллект__Искусственный интеллект в медицине'},
#   {'column_title': 'Секции__Искусственный интеллект__Искусственный интеллект в медицине.1'},
#   {'column_title': 'Секции__Искусственный интеллект__Искусственный интеллект в медицине.2'},
#   {'column_title': 'Секции__Искусственный интеллект__Интеллектуальные сервисы и приложения'},
#   {'column_title': 'Секции__Искусственный интеллект__Интеллектуальные сервисы и приложения.1'},
#   {'column_title': 'Секции__Искусственный интеллект__Интеллектуальные сервисы и приложения.2'},
#   {'column_title': 'Секции__Искусственный интеллект__Системы искусственного интеллекта и больших данных'},
#   {'column_title': 'Секции__Искусственный интеллект__Системы искусственного интеллекта и больших данных.1'},
#   {'column_title': 'Секции__Искусственный интеллект__Системы искусственного интеллекта и больших данных.2'},
#   {'column_title': 'Секции__Науки о жизни__Молекулярная биология и биотехнология'},
#   {'column_title': 'Секции__Науки о жизни__Молекулярная биология и биотехнология.1'},
#   {'column_title': 'Секции__Науки о жизни__Молекулярная биология и биотехнология.2'},
#   {'column_title': 'Секции__Науки о жизни__Экотехнологии'},
#   {'column_title': 'Секции__Науки о жизни__Экотехнологии.1'},
#   {'column_title': 'Секции__Науки о жизни__Экотехнологии.2'},
#   {'column_title': 'Секции__Науки о жизни__Устойчивое развитие'},
#   {'column_title': 'Секции__Науки о жизни__Устойчивое развитие.1'},
#   {'column_title': 'Секции__Науки о жизни__Устойчивое развитие.2'},
#   {'column_title': 'Секции__Науки о жизни__Infochemistry and Interdisciplinary research / Инфохимия и междисциплинарные исследования'},
#   {'column_title': 'Секции__Науки о жизни__Infochemistry and Interdisciplinary research / Инфохимия и междисциплинарные исследования.1'},
#   {'column_title': 'Секции__Науки о жизни__Infochemistry and Interdisciplinary research / Инфохимия и междисциплинарные исследования.2'},
#   {'column_title': 'Секции__Науки о жизни__Synthetic Biology and Gene Therapy'},
#   {'column_title': 'Секции__Науки о жизни__Synthetic Biology and Gene Therapy.1'},
#   {'column_title': 'Секции__Науки о жизни__Synthetic Biology and Gene Therapy.2'},
#   {'column_title': 'Секции__Науки о жизни__Химия для энергетических технологий'},
#   {'column_title': 'Секции__Науки о жизни__Химия для энергетических технологий.1'},
#   {'column_title': 'Секции__Науки о жизни__Химия для энергетических технологий.2'},
#   {'column_title': 'Секции__Науки о жизни__ФудТех'},
#   {'column_title': 'Секции__Науки о жизни__ФудТех.1'},
#   {'column_title': 'Секции__Науки о жизни__ФудТех.2'},
#   {'column_title': 'Секции__Науки о жизни__Индустриальная биотехнология'},
#   {'column_title': 'Секции__Науки о жизни__Индустриальная биотехнология.1'},
#   {'column_title': 'Секции__Науки о жизни__Индустриальная биотехнология.2'},
#   {'column_title': 'Секции__Физика и Инженерия__Техническое зрение'},
#   {'column_title': 'Секции__Физика и Инженерия__Техническое зрение.1'},
#   {'column_title': 'Секции__Физика и Инженерия__Техническое зрение.2'},
#   {'column_title': 'Секции__Физика и Инженерия__Инженерия цифровых систем'},
#   {'column_title': 'Секции__Физика и Инженерия__Инженерия цифровых систем.1'},
#   {'column_title': 'Секции__Физика и Инженерия__Инженерия цифровых систем.2'},
#   {'column_title': 'Секции__Физика и Инженерия__Световодная фотоника и программируемая электроника'},
#   {'column_title': 'Секции__Физика и Инженерия__Световодная фотоника и программируемая электроника.1'},
#   {'column_title': 'Секции__Физика и Инженерия__Световодная фотоника и программируемая электроника.2'},
#   {'column_title': 'Секции__Физика и Инженерия__Прикладная оптика / APPLIED OPTICS'},
#   {'column_title': 'Секции__Физика и Инженерия__Прикладная оптика / APPLIED OPTICS.1'},
#   {'column_title': 'Секции__Физика и Инженерия__Прикладная оптика / APPLIED OPTICS.2'},
#   {'column_title': 'Секции__Физика и Инженерия__Лазерные технологии'},
#   {'column_title': 'Секции__Физика и Инженерия__Лазерные технологии.1'},
#   {'column_title': 'Секции__Физика и Инженерия__Лазерные технологии.2'},
#   {'column_title': 'Секции__Физика и Инженерия__Фундаментальные и прикладные вопросы фотоники'},
#   {'column_title': 'Секции__Физика и Инженерия__Фундаментальные и прикладные вопросы фотоники.1'},
#   {'column_title': 'Секции__Физика и Инженерия__Фундаментальные и прикладные вопросы фотоники.2'},
#   {'column_title': 'Секции__Физика и Инженерия__Техника и технологии сжиженного природного газа'},
#   {'column_title': 'Секции__Физика и Инженерия__Техника и технологии сжиженного природного газа.1'},
#   {'column_title': 'Секции__Физика и Инженерия__Техника и технологии сжиженного природного газа.2'},
#   {'column_title': 'Секции__Физика и Инженерия__Квантовая и информационная оптика'},
#   {'column_title': 'Секции__Физика и Инженерия__Квантовая и информационная оптика.1'},
#   {'column_title': 'Секции__Физика и Инженерия__Квантовая и информационная оптика.2'},
#   {'column_title': 'Секции__Физика и Инженерия__Физика наноструктур'},
#   {'column_title': 'Секции__Физика и Инженерия__Физика наноструктур.1'},
#   {'column_title': 'Секции__Физика и Инженерия__Физика наноструктур.2'},
#   {'column_title': 'Секции__Физика и Инженерия__Практико-ориентированное молодежное научно-техническое творчество'},
#   {'column_title': 'Секции__Физика и Инженерия__Практико-ориентированное молодежное научно-техническое творчество.1'},
#   {'column_title': 'Секции__Физика и Инженерия__Практико-ориентированное молодежное научно-техническое творчество.2'},
#   {'column_title': 'Секции__Физика и Инженерия__Современные функциональные материалы для устройств передачи данных'},
#   {'column_title': 'Секции__Физика и Инженерия__Современные функциональные материалы для устройств передачи данных.1'},
#   {'column_title': 'Секции__Физика и Инженерия__Современные функциональные материалы для устройств передачи данных.2'},
#   {'column_title': 'Секции__Физика и Инженерия__Мастерская будущего'},
#   {'column_title': 'Секции__Физика и Инженерия__Мастерская будущего.1'},
#   {'column_title': 'Секции__Физика и Инженерия__Мастерская будущего.2'},
#   {'column_title': 'Секции__Физика и Инженерия__Компьютерные и кибер-физические системы, сети и технологии'},
#   {'column_title': 'Секции__Физика и Инженерия__Компьютерные и кибер-физические системы, сети и технологии.1'},
#   {'column_title': 'Секции__Физика и Инженерия__Компьютерные и кибер-физические системы, сети и технологии.2'},
#   {'column_title': 'Секции__Хемоинформатика и химическая инженерия__Химия и искусственный интеллект'},
#   {'column_title': 'Секции__Хемоинформатика и химическая инженерия__Химия и искусственный интеллект.1'},
#   {'column_title': 'Секции__Хемоинформатика и химическая инженерия__Химия и искусственный интеллект.2'},
#   {'column_title': 'Секции__Хемоинформатика и химическая инженерия__Хемоинформатика и химическая инженерия'},
#   {'column_title': 'Секции__Хемоинформатика и химическая инженерия__Хемоинформатика и химическая инженерия.1'},
#   {'column_title': 'Секции__Хемоинформатика и химическая инженерия__Хемоинформатика и химическая инженерия.2'},
#   {'column_title': 'Секции__Человек и цифровое будущее: науки, искусства и благополучие__Цифровая история и социально-гуманитарные междисциплинарные исследования'},
#   {'column_title': 'Секции__Человек и цифровое будущее: науки, искусства и благополучие__Цифровая история и социально-гуманитарные междисциплинарные исследования.1'},
#   {'column_title': 'Секции__Человек и цифровое будущее: науки, искусства и благополучие__Цифровая история и социально-гуманитарные междисциплинарные исследования.2'},
#   {'column_title': 'Секции__Человек и цифровое будущее: науки, искусства и благополучие__Доказательные практики в науках о здоровье и научной коммуникации'},
#   {'column_title': 'Секции__Человек и цифровое будущее: науки, искусства и благополучие__Доказательные практики в науках о здоровье и научной коммуникации.1'},
#   {'column_title': 'Секции__Человек и цифровое будущее: науки, искусства и благополучие__Доказательные практики в науках о здоровье и научной коммуникации.2'},
#   {'column_title': 'Секции__Человек и цифровое будущее: науки, искусства и благополучие__Гуманитарные методы в цифровых исследованиях / Digital +/- Humanities'},
#   {'column_title': 'Секции__Человек и цифровое будущее: науки, искусства и благополучие__Гуманитарные методы в цифровых исследованиях / Digital +/- Humanities.1'},
#   {'column_title': 'Секции__Человек и цифровое будущее: науки, искусства и благополучие__Гуманитарные методы в цифровых исследованиях / Digital +/- Humanities.2'},
#   {'column_title': 'Секции__Человек и цифровое будущее: науки, искусства и благополучие__Искусство, наука и технологии'},
#   {'column_title': 'Секции__Человек и цифровое будущее: науки, искусства и благополучие__Искусство, наука и технологии.1'},
#   {'column_title': 'Секции__Человек и цифровое будущее: науки, искусства и благополучие__Искусство, наука и технологии.2'},
#   {'column_title': 'Секции__Энергоэффективные инженерные системы и технологии СПГ__Энергоэффективные инженерные системы и технологии СПГ'},
#   {'column_title': 'Секции__Энергоэффективные инженерные системы и технологии СПГ__Энергоэффективные инженерные системы и технологии СПГ.1'},
#   {'column_title': 'Секции__Энергоэффективные инженерные системы и технологии СПГ__Энергоэффективные инженерные системы и технологии СПГ.2'},
#   {'column_title': 'Секции__Энергоэффективные инженерные системы и технологии СПГ__Техника и технология сжиженного природного газа'},
#   {'column_title': 'Секции__Энергоэффективные инженерные системы и технологии СПГ__Техника и технология сжиженного природного газа.1'},
#   {'column_title': 'Секции__Энергоэффективные инженерные системы и технологии СПГ__Техника и технология сжиженного природного газа.2'},
#   {'column_title': 'Секции__Энергоэффективные инженерные системы и технологии СПГ__Эффективные инженерные решения в энергомашиностроении'},
#   {'column_title': 'Секции__Энергоэффективные инженерные системы и технологии СПГ__Эффективные инженерные решения в энергомашиностроении.1'},
#   {'column_title': 'Секции__Энергоэффективные инженерные системы и технологии СПГ__Эффективные инженерные решения в энергомашиностроении.2'}],
#  'documents': ['В Конгрессе имеют право участвовать молодые ученые, ведущие научно-исследовательскую деятельность по профилю объявленных секций и научных школ, имеющие следующие статусы:\nшкольник\nбакалавр\nмагистрант\nаспирант\nсотрудник вуза\nдругой статус\nУчастниками Конгресса могут быть представители образовательных учреждений, научных организаций и производственных предприятий.\nК участию в Конгрессе допускаются участники и группы участников (не более трех соавторов в каждом докладе), участники могут указать руководителей и консультантов (не более двух в каждом тезисе доклада).\nВыступать с докладом в ОНЛАЙН формате могут те участники, доклады которых включены в программу Конгресса.\nУчастие одного автора в различных секциях не ограничивается. Выступать с одинаковым докладом на разных секциях запрещено.',
#   'Статьи будут проходить рецензирование, проверку на оригинальность в системе «Антиплагиат» и оформляться по требованиям изданий ИТМО и Сборника трудов Конгресса.\nДля сборника трудов Конгресса - оригинальность статьи должна составлять не менее 70 процентов.',
#   'C целью стимулирования научно-технической деятельности молодых ученых, приобретения ими опыта публичных выступлений, повышения научного уровня и апробации выпускных квалификационных работ магистрантов и бакалавров за 2024/2025 учебный год.',
#   'https://drive.google.com/file/d/1KvIKEgQm8LMLEd-fdMFbmY5WzG0RLWLi/view',
#   'На секции обсуждаются актуальные вопросы, связанные с управлением результатами интеллектуальной деятельности в современных реалиях, включающие в себя экономический, маркетинговый, правовой, технический и социальные аспекты изобретательской деятельности, работы\nс произведениями науки и искусства, объектами патентного права, товарными знаками, секретами производства и иными нематериальными активами, обеспечивающими конкурентное преимущество различным участникам рынка.\nВ рамках заседания секции проводится конкурс докладов на поступление в магистратуру Университета ИТМО на программу 27.04.08 «Стратегическое управление интеллектуальной собственностью».',
#   'Русский, Английский',
#   'Онлайн',
#   'Секция посвящена успешным практикам и процессам "трансформации" в широком контексте: не только цифровая, но и трансформация бизнеса в кризисных ситуациях, эволюционная стратегическая и организационная трансформации и многое другое.\nТрансформация бизнеса – это программа системных преобразований, технологических инструментов, управленческих воздействий, цель которых – сделать бизнес эффективнее и конкурентоспособнее на внутреннем и внешних рынках.',
#   'Русский',
#   'Онлайн',
#   'Секция посвящена вопросам контрастивной лингвистики в рамках сопоставления русского языка с языками мира и проблемам межкультурной коммуникации. Внимание будет уделено и проблемам адаптации, с которыми сталкиваются иностранные студенты, приезжая на учёбу в России. К участию приглашаются иностранные студенты, изучающие русский язык.',
#   'Русский',
#   'Гибридный',
#   'Секция посвящена изучению явлений и взаимосвязей в бизнесе и экономике, которые становятся видимыми благодаря использованию цифровых данных. Основное внимание уделяется анализу цифровых следов, включая данные социальных сетей, интернет-платформ и транзакций, а также их роли в понимании социальных и экономических процессов. Участники обсудят результаты исследований с использованием современных методов анализа данных, таких как машинное обучение, текстовый анализ, сетевой анализ, методы обработки больших данных и т.д.\nВ рамках секции будут также рассмотрены вопросы влияния цифровизации на экономическое развитие, поведение организаций и потребителей, а также цифровое неравенство как фактор, формирующий доступ к современным ресурсам и технологиям. Темы секции охватывают исследования цифровой экономики, динамики рыночных взаимодействий и трансформации бизнес-моделей, акцентируя внимание на междисциплинарных подходах и научной валидности представленных методов.',
#   'Русский, Английский',
#   'Гибридный',
#   'Секция посвящена исследованиям в области инновационных IT-решений, цифровой трансформации и устойчивого развития бизнеса.\nВ центре внимания — технологии больших данных, искусственного интеллекта, организационных инноваций, автоматизации и блокчейна, а также их роль в повышении эффективности управления компаниями. Участники обсудят примеры внедрения цифровых решений в различных секторах экономики, включая ритейл, финансы и производство.\nИсследования затрагивают аспекты взаимодействия IT-инноваций с организационной культурой и стратегиями компаний. Особое внимание будет уделено цифровым экосистемам, платформенным бизнес-моделям и новым инструментам анализа поведения потребителей.',
#   'Русский, Английский',
#   'Гибридный',
#   'Секция посвящена научным исследовательским работам школьников в области технологического менеджмента и управления инновациями.\nУчастники представят свои исследования, затрагивающие развитие инновационных продуктов, внедрение новых бизнес-моделей и образовательных проектов, направленных на развитие предпринимательских и исследовательских навыков.\nОсновная цель работы секции — выявить и поддержать школьников с высоким потенциалом в проектной деятельности, а также обсудить кейсы из практики управления инновациями и перспективы цифровизации в различных отраслях.\nПобедители и призёры конкурса докладов получат 5 дополнительных баллов индивидуальных достижений при поступлении в Университет ИТМО, включая образовательные программы бакалавриата «Бизнес-информатика» и «Технологии и инновации».',
#   'Русский, Английский',
#   'Гибридный',
#   'Работа секции сосредоточится на интеграции технологий искусственного интеллекта в управлении и инновациях.\nУчастники обсудят, как ИИ может оптимизировать процессы менеджмента, улучшить принятие решений на основе данных и способствовать развитию новых бизнес-моделей. Основные темы включают использование технологий искусственного интеллекта в управлении, этические аспекты их применения, влияние на человеческий потенциал и возможности для кросс-дисциплинарного сотрудничества.',
#   'Русский, Английский',
#   'Онлайн',
#   'Инклюзивная образовательная среда или инклюзивное пространство представляют собой процесс включения людей с ограниченными возможностями здоровья и инвалидностью в полноценную общественную жизнь.\nСовременная инклюзия охватывает не только инфраструктуру, но также образовательный процесс, рабочие места и общественные пространства. В рамках секции будут рассмотрены темы, раскрывающие основные компоненты формирования инклюзивной среды и общие подходы к обеспечению доступности в приоритетных сферах жизнедеятельности.',
#   'Русский',
#   'Онлайн',
#   'Секция посвящена различным аспектам теории и практики программирования.\nДля выступления на секции приглашаются работы по следующим направлениям:\n• Построение и анализ алгоритмов;\n• Проектирование архитектуры сложных программных комплексов;\n• Высоконагруженные системы (highload);\n• Высокопроизводительные вычисления (HPC) включая исследования повышения производительности и методики её замеров;\n• Теория и практика компиляторов, включая методы оптимизации компилируемы программ, JIT, AOT;\n• Средства разработки включая CI/CD, инструменты сборки, отладки, анализа кода, рефакторинга и другие;\n• Практики тестирования сложных систем;\n• Системное программирование;\n• Работа со спецвычислителями, включая видеокарты, ПЛИС и другие;\n• Информационная безопасность;\n• Парадигмы программирования, метапрограммирование;\n• Низкоуровневое программирование и встроенные системы;\n• Графика и игровые движки;\n• Многопоточность, асинхронность и конкурентность.',
#   'Русский, Английский',
#   'Онлайн',
#   'Биоинформатика — это относительно новая междисциплинарная область, направленная на разработку вычислительных методов и программных комплексов для анализа биологических данных.\nУчёные в этой области применяют и разрабатывают математические модели, включая методы работы с большими массивами данных, для формирования и проверки важных гипотез.\nВ рамках данной секции рассматриваются темы, связанные с применением компьютерных наук для интерпретации генетических, диагностических и клинических данных с целью получения новых результатов в медицине и биологии.',
#   'Русский, Английский',
#   'Онлайн',
#   'Секция «Информационная безопасность, проектирование, технология элементов и узлов компьютерных систем» посвящена вопросам обеспечения безопасности современных систем обработки, хранения и передачи информации.\nСекция охватывает следующие актуальные проблемы:\nсетевая безопасность;\nобеспечение безопасности баз данных;\nбезопасность мобильных систем;\nантивирусные средства защиты;\nсистемы управления доступом;\nкриптографические методы защиты информации;\nдругие аспекты информационной безопасности.\nК участию приглашаются молодые ученые, аспиранты, магистранты и бакалавры для апробации результатов своих научных работ и проектов.\nСекция является площадкой для обсуждения актуальных угроз безопасности и изучения новых технологий защиты\nсовременных систем.',
#   'Русский, Английский',
#   'Гибридный',
#   'Секция посвящена исследовательским и практическим направлениям, связанным с разработкой мультимедиа и графических технологий. Основные темы секции включают:\nдизайн графических интерфейсов;\nразработка компьютерных игр;\nтрёхмерное моделирование и визуализация;\nразработка графических и веб-приложений;\nкомпьютерная графика и мультимедиа в образовании;\nпрограммирование в сфере мультимедиа-технологий;\nтехнологии расширенной реальности (VR/AR/MR);\nпроектирование интерфейсов (UX/UI).\nСекция предоставляет возможность обменяться опытом, представить результаты исследований и разработок, а также обсудить актуальные вопросы в области мультимедиа и графических технологий.',
#   'Русский, Английский',
#   'Очный',
#   'Секция «Интеллектуальные инфокоммуникационные технологии» Конгресса молодых ученых Университета ИТМО реализуется факультетом ИКТ и посвящена следующим вопросам:\nанализ методов машинного обучения в когнитивных инфокоммуникационных системах;\nпроектирование и реализация нейросетевых математических моделей в рамках современных технологий программирования;\nпостроение высокопроизводительных систем анализа больших данных;\nмоделирование, проектирование и разработка программного обеспечения инфокоммуникационных систем;\nпроектирование и разработка мобильных и веб-сервисов;\nанализ и проектирование сетевой инфраструктуры и центров обработки данных;\nинтеллектуальные транспортные технологии.\nК участию приглашаются молодые ученые, магистранты и бакалавры, имеющие научные и практические результаты и желающие получить подтверждение их апробации.\nВ работе секции активно участвуют ученые и IT-специалисты, занимающиеся интеллектуальной обработкой современных данных.',
#   'Русский',
#   'Онлайн',
#   'Секция посвящена решению вопросов математического моделирования объектов различной физической природы, включая объекты и процессы в актуальных направлениях, таких как квантовые коммуникации и интеллектуальные системы.\nОсобое внимание уделяется применению математического аппарата для решения разнообразных задач, возникающих в различных областях науки и техники.\nСекция будет интересна студентам и молодым исследователям, интересующимся наукой в области прикладной математики и информатики.',
#   'Русский',
#   'Онлайн',
#   'Секция «Мобильная разработка» Конгресса молодых ученых Университета ИТМО реализуется факультетом ИКТ и посвящена следующим вопросам:\nпроектирование, разработка и внедрение мобильных и веб-приложений для обеспечения IT-сектора экономики Российской Федерации;\nразработка методов и алгоритмов интеллектуального анализа данных и машинного обучения;\nприменение технологий глубокого обучения и автоматической обработки текстов;\nразработка систем поддержки принятия решений;\nинтеллектуализация мобильных и веб-приложений с учётом предпочтений пользователей;\nпрогнозирование развития мобильных и сетевых технологий;\nразработка организационного и технологического обеспечения, выявление требований к мобильным приложениям для автоматизации задач организационного управления и бизнес-процессов.\nК участию приглашаются молодые ученые, магистранты и бакалавры, обладающие научными и практическими результатами и желающие получить подтверждение их апробации.\nВ рамках работы секции активно участвуют учёные и IT-специалисты, занимающиеся разработкой мобильных приложений и методов интеллектуального анализа данных.',
#   'Русский',
#   'Онлайн',
#   'Секция посвящена вопросам теории автоматического управления, а также исследованиям в области электроэнергетики и электроинженерии, включая алгоритмы управления такими системами.\nСекция будет интересна студентам всех уровней образования, которые заинтересованы в системах автоматического управления, особенно в контексте электроинженерии.',
#   'Русский',
#   'Секция посвящена технологиям современного цифрового производства.\nВ рамках секции рассматриваются следующие вопросы:\nразработка и совершенствование технологических процессов изготовления и контроля деталей и изделий различного назначения;\nприменение цифровых технологий на различных этапах производства;\nавтоматизация технологических процессов и производств.\nСекция будет интересна обучающимся, которые идут в ногу со временем и изучают вопросы современного производства.',
#   'Русский',
#   'Секция посвящена разработке и управлению мехатронными и робототехническими устройствами.\nВ рамках секции также рассматриваются доклады из стремительно развивающейся области компьютерного зрения, применяемого для сенсорного обеспечения сложных технических объектов.\nСекция будет интересна как обучающимся, занимающимся научной деятельностью, так и тем, кто ориентируется на инженерную направленность.',
#   'Русский',
#   'Секция «Инновационные технологии и методы в разработке видеоигр» Конгресса молодых ученых Университета ИТМО реализуется факультетом ШРВ и посвящена вопросам:\n- Визуализация и компьютерная графика реального времени;\n- Искусственный интеллект в разработке видеоигр;\n- Разработка и применение ИИ-инструментов для создания виртуальных миров;\n- Технологии анимации, симуляции и физического моделирования;\n- Инструменты и пайплайны разработки игр: автоматизация и повышение эффективности;\n- Анализ игрового опыта и человеко-машинное взаимодействие в играх;\n- Иммерсивные технологии и игровые интерфейсы.',
#   'Русский',
#   'Онлайн',
#   'Магистерская программа "Нейротехнологии и программная инженерия", 09.04.04 Программная инженерия, факультет ПИиКТ.\n\nНа секцию принимаются доклады, посвященные результатам разработки и исследования программных продуктов, имеющих научное и(или) практическое значение для решения проблем ключевых сегментов рынка НТИ НейроНет, а именно:\nпроект COBRAIN (работа мозга человека на основе сбора и обработки данных с различных датчиков),\nНейроРазвлечения и спорт (игровые технологии для тренинга когнитивных способностей человека,\nкоррекции функциональных состояний человека),\nНейроОбразование (нейроинтерфейсы и образовательные технологии для расширения ресурсов мозга),\nНейроКоммуникации и маркетинг (прогнозирование поведения человека при взаимодействии и работе в коллективе),\nНейроАссистенты (технологии понимания естественного языка, создание персональных электронных ассистентов).',
#   'Русский',
#   'Очный',
#   'Магистерская программа "Системное и прикладное программное обеспечение", "09.04.04 Программная инженерия", факультет ПИиКТ, магистерская программа "Веб-технологии", "09.04.04 Программная инженерия", факультет ПИиКТ.\n\nНа секцию принимаются доклады, посвященные результатам исследовании разработок в области:\nсистемного и прикладного программирования;\nтехнологий промышленного программирования и разработки программных продуктов;\nинженерии знаний, информационного поиска, извлечения знаний из неформализованных источников;\nинтеллектуальных мобильных и Web-приложений;\nтехнологий хранения и обработки больших данных, практического применения нейросетевых технологий и машинного обучения;\nметодов обработки изображений и технологий компьютерной визуализации\nинтернета вещей и умного дома.',
#   'Русский',
#   'Онлайн',
#   'Русский',
#   'Гибридный',
#   'На секцию принимаются доклады, посвященные результатам разработки и исследования веб-приложений, в том числе на стороне фронтенда и бэкенда, исследования веб-языков, веб-фреймворков и других компонентов экосистем веб-технологий:\n\n- импортозамещение веб-технологий и веб-инструментов,\n- развитие веб-языков (JavaScript, TypeScript и др.)\n- производительность приложений на платформах веб-языков,\n- доступность веб-приложений и веб-интерфейсов для людей с ограничениями по функциям восприятия.',
#   'Русский',
#   'Онлайн',
#   'Секция «Цифровая урбанистика» Конгресса молодых ученых Университета ИТМО посвящена вопросам применения современных информационных технологий, математического и компьютерного моделирования для решения актуальных задач урбанистики, градостроительства и управления развитием городов.\nОсобое внимание уделяется исследованиям, направленным на внедрение методов искусственного интеллекта и машинного обучения в реальные процессы управления и развития городов, а также на анализ связанных с этим проблем и барьеров.\nОсновные тематики секции:\nсбор, обработка и систематизация данных для управления урбанизированными территориями;\nметоды пространственного анализа в прикладных задачах урбанистики;\nметоды машинного обучения и искусственного интеллекта в урбанистике;\nвнедрение цифровых технологий в градостроительной деятельности;\nприменение технологий анализа данных в социологии города;\nиспользование цифровых технологий для формирования городской идентичности;\nценностно-ориентированные методы управления развитием урбанизированных территорий.\nК участию приглашаются молодые ученые, магистранты и бакалавры, занимающиеся междисциплинарными исследованиями в области управления урбанизированными территориями и интересующиеся применением современных технологий в своей деятельности.\nСекция направлена на создание дискуссионной площадки для встречи представителей различных дисциплинарных направлений и на содействие развитию участников как в профессиональной сфере, так и в общекультурной.',
#   'Русский',
#   'Гибридный',
#   'Фокус секции направлен на развитие теории машинного обучения, доказательные исследования и применение передовых методов в практических задачах.\nК участию приглашаются работы по следующим направлениям:\nтеория искусственных нейронных сетей, включая глубокое обучение;\nгенеративные модели искусственного интеллекта;\nглубокое обучение с подкреплением;\nстатистическая и вычислительная сложность обучения;\nметоды оптимизации для обучения;\nвыбор алгоритмов, моделей и методов оценки качества;\nперенос знаний, доменная адаптация, обучение с нескольких взглядов;\nгеометрические и топологические структуры в данных, обучение многообразий;\nтеоретический анализ вероятностных графических моделей;\nбайесовские методы обучения и анализ неопределенности глубоких нейронных сетей;\nобучение с системными ограничениями (например, конфиденциальность, честность, память, общение);\nоптимальный транспорт.\nТакже принимаются работы по другим смежным направлениям.',
#   'Русский, Английский',
#   'Онлайн',
#   'Системы искусственного интеллекта обладают «способностями», которые позволяют применять их в задачах, где важны высокая производительность анализа информации, быстрое принятие решений и корректное реагирование для устранения различных угроз.\nВ рамках секции будут рассмотрены темы применения ИИ для обеспечения безопасности, обнаружения угроз и построения защитных и предохранительных систем. Среди обсуждаемых вопросов:\nвыявление опасных объектов с помощью систем распознавания образов;\nанализ правильности применения средств защиты;\nобработка сигналов от датчиков безопасности;\nоценка поведения объектов и выявление специфических паттернов в нём.\nТакже приветствуются доклады на тему:\nсоздания предохранительных механизмов для самого искусственного интеллекта;\nразработки алгоритмов обратной связи;\nоценки принимаемых ИИ решений с точки зрения этики и безопасности.',
#   'Русский, Английский',
#   'Онлайн',
#   'Секция «Аналитика данных» Конгресса молодых ученых Университета ИТМО направлена на продвижение научных и промышленных исследовательских проектов, связанных с интеллектуальным анализом данных.\nОсобое внимание уделяется применению современных методов машинного обучения и искусственного интеллекта для выявления прогнозов и неочевидных зависимостей в данных. Современная аналитика данных сочетает в себе мощь математики, статистики и искусственного интеллекта, предоставляя эффективные инструменты для решения задач различного масштаба — от обработки и анализа больших массивов данных до моделирования сложных процессов. Навыки анализа данных находят применение в самых разнообразных сферах: от научных исследований до бизнеса и образования.\nКлючевые направления секции:\nКлассическое машинное обучение и алгоритмы обработки данных\nОбсуждение методов оптимизации алгоритмов машинного обучения, их интерпретации и применения для работы с разнообразными наборами данных.\nГлубокое обучение и его применения\nИсследования в области нейронных сетей, включая обучение с подкреплением, работу с большими архитектурами и их адаптацию для решения реальных задач.\nГрафовые нейронные сети и алгоритмы на графах\nАлгоритмы обработки графовых структур и использование GNN для анализа сложных связей в социальных сетях, биоинформатике, логистике и других областях.\nОбработка естественного языка (NLP)\nТехнологии анализа текстовых данных, включая автоматическое распознавание, тематическое моделирование, построение диалоговых систем и извлечение знаний из текстов.\nОбработка изображений и компьютерное зрение\nРешение задач сегментации, классификации и генерации изображений, а также применение глубоких архитектур для обработки визуальных данных.\nАнализ звука и речи\nАктуальные разработки в области распознавания речи, генерации аудио и улучшения качества звуковых данных.\nСистемы управления базами данных (СУБД)\nРазработка решений для эффективного хранения, обработки и анализа структурированных и неструктурированных данных. Особое внимание уделяется гибридным подходам и оптимизации запросов.\nУчастники секции приглашаются представить свои исследования и проекты в указанных направлениях, обогатив общий обзор современных достижений в области аналитики данных.\nСекция «Аналитика данных» приглашает всех заинтересованных ознакомиться с более подробной информацией о ключевых направлениях исследований на нашем веб-сайте [https://dc.itmo.ru/analytic_master].',
#   'Русский, Английский',
#   'Гибридный',
# ...
#   'Русский, Английский',
#   'Гибридный',
#   'ФудТех — это направление, ориентированное на разработку инновационных продуктов питания, управление качеством, сертификацию продукции и обеспечение продовольственной безопасности страны.\nСпециалисты, работающие в данной области, выступают лидерами пищевой промышленности. Они обладают глубокими знаниями и навыками в разработке, производстве, управлении качеством и сертификации пищевой продукции, способствуя развитию устойчивого и инновационного сектора продовольствия.',
#   'Русский',
#   'Онлайн',
#   'Индустриальная биотехнология — это направление, охватывающее разработку, производство, управление качеством, валидацию и сертификацию биотехнологической продукции, а также вопросы лекарственной и продовольственной безопасности.\nСпециалисты, работающие в этой области, являются лидерами индустрии. Они обладают широким спектром компетенций, которые позволяют им решать задачи в различных сферах биотехнологической индустрии, способствуя её устойчивому развитию и инновациям.',
#   'Русский',
#   'Онлайн',
#   'Тематика секции охватывает вопросы, связанные с регистрацией, обработкой и анализом изображений и видео, полученных в широком диапазоне длин волн (от рентгеновского до радиодиапазона) в системах технического зрения различного назначения. Примеры применения включают биологию, медицину, искусство, приборостроение, промышленность и другие области.\nКроме того, будут рассмотрены специальные вопросы, связанные с разработкой систем технического зрения.\nУчастники секции имеют возможность поступить в магистратуру Университета ИТМО без экзаменов на программу «Техническое зрение» по направлению 12.04.02 Оптотехника.',
#   'Русский, Английский',
#   'Гибридный',
#   'Инженерия цифровых систем — это междисциплинарное направление, находящееся на стыке электроники, программирования и алгоритмизации.\nВ рамках секции рассматриваются доклады по следующим темам:\nцифровая и аналоговая электроника;\nпрограммирование на различных уровнях абстракции (от ПЛИС до ПК);\nалгоритмия и методы цифровой обработки сигналов.\nОтличительной чертой секции является её практико-ориентированность, направленная на создание и разработку новых устройств и датчиков физических величин.',
#   'Русский, Английский',
#   'Онлайн',
#   'Секция посвящена технологиям современного цифрового производства.\nВ рамках секции рассматриваются следующие вопросы:\nразработка и совершенствование технологических процессов изготовления и контроля деталей и изделий различного назначения;\nприменение цифровых технологий на различных этапах производства;\nавтоматизация технологических процессов и производств.\nСекция будет интересна обучающимся, которые стремятся идти в ногу со временем и изучают современные подходы к производственным процессам.',
#   'Русский',
#   'Онлайн',
#   'Секция посвящена следующим темам:\nрасчёт оптических систем различного назначения;\nмоделирование оптических систем;\nвычислительная оптика;\nкомпьютерная обработка изображений;\nпроектирование оптических систем;\nсветотехнические и энергетические расчёты;\nсистемы обработки спектров;\nспектральные и поляризационные приборы;\nмедицинская оптика;\nастрономическая оптика.\nСекция будет интересна обучающимся, увлечённым прикладной оптикой, а также вопросами расчёта, проектирования и компьютерного моделирования оптических систем.',
#   'Русский, Английский',
#   'Онлайн',
#   'Направления работы секции:\nлазерная техника;\nлазерные технологии.\nСекция охватывает исследования и разработки в области лазерных систем, их применения в различных отраслях, а также инновационные подходы к использованию лазерных технологий.',
#   'Русский',
#   'Гибридный',
#   'В данной секции мы сосредоточимся на ключевых аспектах фотоники, включая как теоретические основы, так и практические применения. Участники смогут обсудить последние достижения в области, оптических материалов, квантовой фотоники и фотонных технологий.',
#   'Русский',
#   'Онлайн',
#   'В рамках секции предполагается заслушать сообщения о научной деятельности, направленной на развитие отечественных технологий получения, хранения, транспортировки и использования сжиженного природного газа (СПГ), а также организацию производства специализированного оборудования для реализации этих технологий.\nПовышение научной активности в этой сфере должно способствовать выполнению планов, намеченных Правительством\nРоссийской Федерации, по увеличению производства СПГ на отечественных предприятиях и обеспечению населения и промышленных предприятий страны доступным природным газом.\nДля выполнения поставленных задач необходимо активно использовать готовые технологические и конструктивные решения из смежных областей науки и техники.\nОбмен профильной научно-технической информацией в рамках секции поможет молодым ученым в работе над их диссертационными исследованиями.',
#   'Русский, Английский',
#   'Онлайн',
#   'Направления работы секции:\nОптические квантовые технологии;\nФантомная визуализация;\nИнформационная оптика;\nКвантовая теория информации;\nНелинейная и фемтосекундная оптика.\nСекция охватывает современные исследования и разработки в области оптики и квантовых технологий, предоставляя возможность обсуждения новейших достижений и перспектив развития этих направлений.',
#   'Русский, Английский',
#   'Онлайн',
#   'Секция посвящена технологиям создания функциональных наноструктур для различных задач фотоники.\nВ рамках секции рассматриваются следующие вопросы:\nсинтез органических и неорганических наноструктур с заданными функциональными характеристиками;\nхарактеризация получаемых наноструктур;\nизучение их структурных, электронных, оптических и магнитных свойств.\nТематика секции также охватывает применение наноструктур и материалов на их основе в решении прикладных задач.\nУчастие в секции предоставляет возможность поступления без экзаменов на магистерскую программу 12.04.03 «Физика и технология наноструктур» / Physics and Technology of Nanostructures.',
#   'Русский',
#   'Онлайн',
#   'Секция посвящена научно-техническому творчеству в различных направлениях науки и технологий.\nВ рамках секции предусмотрена выставка, где участники могут продемонстрировать результаты своей работы. Также возможно проведение круглого стола на тему «Научно-техническое творчество и развитие кадрового потенциала страны», который станет площадкой для обмена опытом между организаторами кружков, секций и мастерских технической направленности.\nУ вас есть разработка?\nПриносите и показывайте!\nУ вас есть частично реализованный проект?\nРасскажите о нём!\nВы руководите проектом или студенческим коллективом?\nРегистрируйтесь для участия в дискуссии!',
#   'Русский',
#   'Гибридный',
#   'Создание современных устройств передачи данных начинается с выбора оптимальных материалов и их структур, основываясь на конструкции и характеристиках разрабатываемого прибора.\nПомимо традиционных полупроводниковых материалов, которые выступают в роли рабочего тела устройства, конструирование приборов передачи данных включает исследование:\nметаллических материалов;\nкомпозитных материалов;\nполимерных материалов.\nЭти материалы используются для отвода тепла, корпусирования, защиты устройства и подвода питания.\nСекция посвящена вопросам исследования, синтеза, обработки и применения новых функциональных материалов в устройствах передачи данных.',
#   'Русский, Английский',
#   'Онлайн',
#   'Секция посвящена промышленному дизайну, мейкерству и протатипированию. Также на секции будут рассматриваться доклады на тему актуальности инжирных профессий в эпоху развития технологий.\nПочему инженера не заменит искусственный интеллект и автоматизация?\nСекция будет интересна для обучающихся всех уровней образования, заинтересованных в создании физических объектов для бизнеса, дома и учебного процесса.',
#   'Русский',
#   'Гибридный',
#   'Новые архитектурные решения и принципы структурно-функциональной организации компьютерных и кибер-физических систем\n- Реконфигурируемые и адаптивные системы\n-Высокопроизводительные вычисления, параллельное и распределенное программирование, облачные вычисления и виртуализация\n- Методология проектирования и разработки компьютерных и кибер-физических систем. Системы автоматизированного проектирования\n- Встроенные системы и системы реального времени. Интернет вещей. - Повсеместные вычисления. Мобильные вычислительные системы\n- Универсальные и специализированные процессоры, системы на кристалле, программируемая логика. Современные инструменты разработки (HLS, ESL, ASIP и др.)\n- Доменно-ориентированное моделирование, совместное моделирование, метамоделирование компьютерных и кибер-физических систем\n- Модели, методы и средства исследования эффективности функционирования компьютерных и кибер-физических систем различных классов\n- Методы и средства повышения надежности и безопасности компьютерных и кибер-физических систем\n- Исследование современных компьютерных и сетевых технологий, их сравнительный анализ.',
#   'Русский, Английский',
#   'Гибридный',
#   'Секция «Химия и искусственный интеллект» создана для тех, кто занимается решением химических задач с использованием новых IT-подходов, работы с большими данными и алгоритмов искусственного интеллекта.\nОсновные направления проектов, рассматриваемые в рамках секции:\nнейронные сети для планирования ретросинтеза молекул и предсказания фармакологических свойств систем адресной доставки;\nмашинное обучение, позволяющее предсказывать свойства неизученных органических молекул и наноматериалов;\nавтоматическая обработка и анализ больших данных;\nметоды расчетной химии для усиления алгоритмов искусственного интеллекта и наработки больших данных;\ndata-driven подходы к решению химических задач;',
#   'Английский',
#   'Онлайн',
#   'Данная секция посвящена работам в области химических и биотехнологических производств с применением современных подходов к цифровому дизайну технологических процессов, а также к разработке структуры и свойств биоинжиниринговых и биотехнических систем.\nОсобое внимание уделяется научным разработкам и результатам исследований в области хемоинформатики и биоинженерии, внедряемым в производство с учетом современных тенденций цифровизации.\nБудут рассмотрены вопросы, связанные с получением и разработкой функциональных материалов, оптимизацией существующих технологий и созданием передовых решений.',
#   'Русский, Английский',
#   'Очный',
#   'Каковы особенности гуманитарных дисциплин и как они взаимодействуют с техническими науками в рамках современных междисциплинарных исследований? Какие открытия совершаются на стыке технического и гуманитарного знания? Как изучение общества и его культуры способствует достижениям в технических исследованиях?\nОбсуждению этих и других вопросов, связанных с социальными и гуманитарными науками, посвящена данная секция. Основное внимание уделяется применению методов исторической науки в реализации междисциплинарных научных исследований.\nНаправление цифровой истории выступает не просто современным трендом, а устойчивым направлением, являющимся одной из основ актуального научного поиска.',
#   'Русский',
#   'Гибридный',
#   'Научная коммуникация — это новая междисциплинарная область знания, формирующаяся вокруг взаимодействия между наукой и обществом. Специалисты в области Public Health Sciences изучают, как болезни, окружающая среда, условия труда, социальный статус, доступ к образованию и другие факторы влияют на здоровье.\nВ рамках секции рассматриваются темы взаимодействия науки, технологий и общества, научной журналистики и PR, научных музеев и рынка научно-популярных проектов, а также исследования evidence-based практик в медицине, научной коммуникации и Public Health.\nОсновные темы, которые могут быть представлены:\nнаучная журналистика;\nPR в университетах, НИИ и наукоёмком бизнесе;\nвзаимодействие науки, технологий и общества;\nисследования центров популяризации науки и научных музеев: акторы, целевая аудитория, популяризация научного знания;\nкоммуникация ученых и стейкхолдеров;\nисследования экспертной среды в научных областях;\nобраз науки и ученых в медиа и визуальной культуре;\nэволюция моделей научной коммуникации (дефицит, диалог, вовлечение);\nанализ рынка и исследования аудиторий научно-популярных проектов;\nдоказательная научная коммуникация;\nдоказательная медицина и оценка эффективности;',
#   'Русский',
#   'Онлайн',
#   'Digital Humanities (DH) — это направление исследований, в рамках которого учёные разрабатывают и применяют цифровые инструменты для решения задач гуманитарных наук.\nСекция «Гуманитарные методы в цифровых исследованиях» предлагает рассмотреть доклады, посвящённые сочетанию методов гуманитарных наук и цифровых инструментов, а также связанных исследований и проектов. Особое внимание уделяется докладам, которые не только представляют результаты, но и позволяют обсудить методологические, концептуальные и этические проблемы, возникающие на стыке гуманитарного и цифрового.\nПримерные тематические направления:\nкритика и осмысление цифровых проектов и исследований;\nцифровизация и внедрение AI в сфере культуры и науки;\nсоциально-гуманитарная экспертиза;\nприменение цифровых инструментов в гуманитарных науках;\nсоциальная и этическая экспертиза технологических решений;',
#   'Русский',
#   'Онлайн',
#   'Секция «Искусство, наука и технологии» посвящена области art&science — взаимодействию художников, философов, учёных и инженеров.\nВ рамках секции можно представить исследования, художественные, кураторские и научные проекты, связанные с применением научных разработок в художественной практике.\nТакже приветствуются доклады на следующие темы:\nфилософия техники;\nкритический постгуманизм;\nэтика науки и технологий;\nвзаимодействие человеческих и нечеловеческих агентов;\nмежвидовые связи;\nмедиархеология и другие смежные направления.',
#   'Русский, Английский',
#   'Онлайн',
#   'Секция «Энергоэффективные инженерные системы и технологии СПГ» Конгресса молодых ученых Университета ИТМО объединяет научные исследования в следующих областях:\nтеплофизика и теоретическая теплотехника;\nкомпрессоростроение;\nхолодильная техника и технологии сжиженного природного газа (СПГ);\nтранспортировка и хранение природного газа и нефтепродуктов;\nдекарбонизация в топливно-энергетическом комплексе;\nинжиниринг энергетических систем, включая возобновляемые источники энергии.\nОсобое внимание уделяется разработке и применению современных технологий и материалов, позволяющих повысить эффективность систем энергообеспечения, транспортировки и преобразования энергии.',
#   'Русский, Английский',
#   'Гибридный',
#   'В рамках работы секции предполагается обсудить вопросы развития оригинальных отечественных технологий производства, хранения и транспортировки сжиженного природного газа.\nЦель секции — обмен передовой научно-технической информацией в области сжижения и разделения газовых смесей. Будут заслушаны доклады, отражающие весь спектр научных исследований молодых специалистов в области техники и технологий сжиженного природного газа.',
#   'Русский, Английский',
#   'Онлайн',
#   'Секция «Эффективные инженерные решения в энергомашиностроении» направлена на развитие научно-исследовательских проектов в области современных конструкторских решений для объектов энергомашиностроения, подкреплённых исследовательской составляющей.\nОбъектами исследования могут быть:\nкомпрессоры объёмного и динамического типа действия;\nмашины и вспомогательное оборудование энергетических систем;\nприменение новых конструкционных материалов;\nметоды проектирования и производства;\nцифровые решения.',
#   'Русский',
#   'Гибридный'],
#  'data': None,
#  'uris': None,
#  'included': ['documents', 'embeddings', 'metadatas']}

# %%
# Получаем текст статьи
# Путь к файлу статьи
article_path = "D:/GitHub/Edulytica/src/rag/data/article.txt"

# Загружаем содержимое файла
with open(article_path, 'r', encoding='utf-8') as file:
    article_text = file.read()

article_text

# Теперь в переменной article_text содержится весь текст из файла
# Out:
# "ДЛЯ РАСПРЕДЕЛЕННОГО ХРАНЕНИЯ ДАННЫХ \nКича И.В.1 (студент), Тимкин А.К.1 (студент) \nНаучный руководитель – к.т.н., доцент ФБИТ Таранов С.В. \n1 – Университет ИТМО \ne-mail: kicha@niuitmo.ru \nВ ходе данной работы были рассмотрены различные методы организации систем \nраспределенных реестров. Были рассмотрены примитивные структуры, древовидные и их \nмодификации. Была проанализирована производительность системы хранения данных при \nиспользовании разных подходов. Были предложены эффективные алгоритмы подтверждения \nналичия блока в цепи. \nКлючевые слова \nРаспределенные реестры, хранение данных, древовидные структуры данных, алгоритмы \nупрощенной проверки оплаты, блокчейн. \nПо данным различных исследования последнее десятилетие возрастает количество \nисследований в области систем распределенных реестров. Таким образом, число \nразработок увеличивается и их область применения расширяется. Одним из таких \nнаправлений является возможность хранения данных. Системы, основанные на \nтехнологии блокчейн, в свою очередь обеспечивают конфиденциальность информации \nи ее целостность, что является их важным преимуществом перед традиционными \nподходами.  При этом существует проблема пропорционального роста размера цепочки \nблоков при добавлении новых данных [3]. \nВ результате изучения одномерных методов организации блокчейна было \nустановлено, что данный метод хранения данных способен осуществлять \nфункционирование систем распределенных реестров на базовом уровне, но при этом \nважной проблемой будет пропорциональный рост размера цепочки блоков при \nдобавлении новых данных. Более того, описанные методы позволяют хранить \nминимальное количество данных, что в свою очередь ставит под вопрос эффективность \nиспользования одномерных последовательных цепочек. Также при введении \nограничения на размер блока возможно замедленное время обработки транзакции в \nбудущем, так как при определенных алгоритмах консенсуса будет увеличиваться время \nгенерации новых блоков. В связи с упомянутыми выводами возникает необходимость \nрассмотрения возможности применения других структур данных в системах \nраспределенного реестра в контексте хранения информации. \nБыло установлено, что древовидные структуры данных позволяют ускорить \nпроцесс проверки валидности блоков по сравнению с хеш-цепочками. Применение \nдеревьев Меркла позволяет получить прирост производительности системы за счет \nуменьшения числа необходимых действий для доказательства существования блока в \nструктуре. Данная возможность породила появление упрощенной проверки оплаты \n(SPV), что позволяет, имея только корень дерева и аутентификационный путь, \nподтверждать данные без необходимости загружать все блоки [1]. На рисунке 1 \nизображен аутентификационный путь к блоку L1, построенный для подтверждения \nналичия этого блока в структуре. \nРис. 1. Аутентификационный путь к блоку L1 \nПри этом стоит упомянуть, что данная технология имеет и недостатки. Так, \nнапример, для вычисления верхнего хеша необходимо знать все промежуточные узлы \nдерева, для чего необходимо либо их хранить в системе, либо вычислять заново при \nкаждом запросе. Первый вариант при больших размерах дерева потребует большего \nколичества места в памяти. Второй в свою очередь повлечет снижение \nпроизводительности системы. Рассмотренная структура данных имеет модификации, \nкоторые следует рассмотреть для более точного анализа вариантов хранения данных с \nпомощью систем распределенных реестров. \nНеобходимо рассмотреть модификацию хеш-дерева – Merkle Patricia Trie, которая \nпредставляет собой дерево Меркла, которое хранит пары ключи значение, где ключи \nявляются последовательностями байтов. Данная структура данных имеет определенную \nорганизацию блоков, которую удобно было бы рассмотреть на примере криптовалютной \nсистемы Ethereum. В данном контексте вводится понятие ниббла – половины байтов – \nпоследовательность которых выступает в дереве ребром. Каждый узел может иметь до \n16 дочерних блоков. \nСущест ...

# %%
import numpy as np

# %% [markdown]
# # №1 Chunks
#
# 1. Clear text
# 2. Simple chanks

# %%
# 1.2. Функция для разбиения текста на чанки
def split_text_to_chunks(text: str,
                         max_chunk_size: int = 500,
                         overlap: int = 50) -> List[str]:
    words = text.split()
    chunks = []
    step = max_chunk_size - overlap
    for i in range(0, len(words), step):
        chunk = " ".join(words[i: i + max_chunk_size])
        chunks.append(chunk)
    return chunks

# Получаем список чанков
chunks = split_text_to_chunks(article_text)

# %%
# 2.1. Вычисляем эмбеддинги для каждого чанка
processor = EmbeddingProcessor()
embed_fn = processor.get_embedding_function()  # SentenceTransformerEmbeddingFunction
chunk_embeddings = embed_fn(chunks)
# Out:
# 2025-04-21 19:17:41.098 | INFO     | rag.core.utils.config_loader:load_config:47 - Configuration loaded successfully: {'count_keywords': 10, 'host': 'localhost', 'port': 8080, 'collections_file': 'all_collections.json', 'embedding_model': 'BAAI/bge-m3'}
# 2025-04-21 19:17:41.099 | INFO     | __main__:__init__:15 - Initializing EmbeddingProcessor with model: BAAI/bge-m3
# 2025-04-21 19:17:41.100 | INFO     | __main__:__init__:20 - Successfully initialized embedding function with model BAAI/bge-m3

# %%
# 3.1. Получаем нужную коллекцию из ChromaDB
chroma_manager = ChromaDBManager()
collection = chroma_manager.get_collection("KMU")
# Загружаем из коллекции всё, что нужно:
contents = collection.get(include=['embeddings', 'documents', 'metadatas'])
col_embs = np.array(contents['embeddings'])        # (N_docs, dim)
docs     = contents['documents']                   # List[str]
mds      = contents['metadatas']
# Out:
# 2025-04-21 19:17:44.256 | INFO     | rag.core.utils.config_loader:load_config:47 - Configuration loaded successfully: {'count_keywords': 10, 'host': 'localhost', 'port': 8080, 'collections_file': 'all_collections.json', 'embedding_model': 'BAAI/bge-m3'}
# 2025-04-21 19:17:44.257 | INFO     | __main__:__init__:18 - Initializing ChromaDBManager with host: localhost, port: 8080
# 2025-04-21 19:17:44.494 | INFO     | __main__:__init__:23 - Successfully connected to ChromaDB
# 2025-04-21 19:17:44.496 | INFO     | __main__:__init__:37 - Created embedding function with model: BAAI/bge-m3
# 2025-04-21 19:17:44.498 | INFO     | __main__:get_collection:101 - Retrieved collection 'KMU'

# %%
# Нормализуем эмбеддинги коллекции:
col_embs_norm   = col_embs / np.linalg.norm(col_embs, axis=1, keepdims=True)

# %%
chunk_embs    = np.array(chunk_embeddings)         # (N_chunks, dim)
chunk_embs_norm = chunk_embs / np.linalg.norm(chunk_embs, axis=1, keepdims=True)

# %%
# косинусная похожесть: матричное умножение
sims_matrix = chunk_embs_norm.dot(col_embs_norm.T)  # (N_chunks, N_docs)
top_k = 5

# %%
results = []
for chunk_idx, sims in enumerate(sims_matrix):
    # индексы top_k документов для данного чанка
    best_idx = np.argsort(-sims)[:top_k]
    for doc_idx in best_idx:
        results.append({
            'chunk': chunk_idx,
            'similarity': float(sims[doc_idx]),
            'text': docs[doc_idx],
            'metadata': mds[doc_idx]
        })

# %%
# отсортируем все найденные пары (чанк,док) по убыванию схожести
results = sorted(results, key=lambda x: -x['similarity'])

# Выведем топ‑10
for r in results[:10]:
    print(f"[chunk {r['chunk']}] sim={r['similarity']:.4f} meta={r['metadata']}")
    print(r['text'])
    print('-'*60)
# Out:
# [chunk 0] sim=0.5526 meta={'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__ФИРМЫ И РЫНКИ: IT-решения для бизнеса / FIRM AND MARKETS: IT-driven solutions'}
# Секция посвящена исследованиям в области инновационных IT-решений, цифровой трансформации и устойчивого развития бизнеса.
# В центре внимания — технологии больших данных, искусственного интеллекта, организационных инноваций, автоматизации и блокчейна, а также их роль в повышении эффективности управления компаниями. Участники обсудят примеры внедрения цифровых решений в различных секторах экономики, включая ритейл, финансы и производство.
# Исследования затрагивают аспекты взаимодействия IT-инноваций с организационной культурой и стратегиями компаний. Особое внимание будет уделено цифровым экосистемам, платформенным бизнес-моделям и новым инструментам анализа поведения потребителей.
# ------------------------------------------------------------
# [chunk 0] sim=0.5443 meta={'column_title': 'Секции__Искусственный интеллект__Аналитика данных'}
# Секция «Аналитика данных» Конгресса молодых ученых Университета ИТМО направлена на продвижение научных и промышленных исследовательских проектов, связанных с интеллектуальным анализом данных.
# Особое внимание уделяется применению современных методов машинного обучения и искусственного интеллекта для выявления прогнозов и неочевидных зависимостей в данных. Современная аналитика данных сочетает в себе мощь математики, статистики и искусственного интеллекта, предоставляя эффективные инструменты для решения задач различного масштаба — от обработки и анализа больших массивов данных до моделирования сложных процессов. Навыки анализа данных находят применение в самых разнообразных сферах: от научных исследований до бизнеса и образования.
# Ключевые направления секции:
# Классическое машинное обучение и алгоритмы обработки данных
# Обсуждение методов оптимизации алгоритмов машинного обучения, их интерпретации и применения для работы с разнообразными наборами данных.
# Глубокое обучение и его применения
# Исследования в области нейронных сетей, включая обучение с подкреплением, работу с большими архитектурами и их адаптацию для решения реальных задач.
# Графовые нейронные сети и алгоритмы на графах
# Алгоритмы обработки графовых структур и использование GNN для анализа сложных связей в социальных сетях, биоинформатике, логистике и других областях.
# Обработка естественного языка (NLP)
# Технологии анализа текстовых данных, включая автоматическое распознавание, тематическое моделирование, построение диалоговых систем и извлечение знаний из текстов.
# Обработка изображений и компьютерное зрение
# Решение задач сегментации, классификации и генерации изображений, а также применение глубоких архитектур для обработки визуальных данных.
# Анализ звука и речи
# Актуальные разработки в области распознавания речи, генерации аудио и улучшения качества звуковых данных.
# Системы управления базами данных (СУБД)
# Разработка решений для эффективного хранения, обработки и анализа структурированных и неструктурированных данных. Особое внимание уделяется гибридным подходам и оптимизации запросов.
# Участники секции приглашаются представить свои исследования и проекты в указанных направлениях, обогатив общий обзор современных достижений в области аналитики данных.
# Секция «Аналитика данных» приглашает всех заинтересованных ознакомиться с более подробной информацией о ключевых направлениях исследований на нашем веб-сайте [https://dc.itmo.ru/analytic_master].
# ------------------------------------------------------------
# [chunk 0] sim=0.5420 meta={'column_title': 'Секции__Физика и Инженерия__Компьютерные и кибер-физические системы, сети и технологии'}
# Новые архитектурные решения и принципы структурно-функциональной организации компьютерных и кибер-физических систем
# - Реконфигурируемые и адаптивные системы
# -Высокопроизводительные вычисления, параллельное и распределенное программирование, облачные вычисления и виртуализация
# - Методология проектирования и разработки компьютерных и кибер-физических систем. Системы автоматизированного проектирования
# - Встроенные системы и системы реального времени. Интернет вещей. - Повсеместные вычисления. Мобильные вычислительные системы
# - Универсальные и специализированные процессоры, системы на кристалле, программируемая логика. Современные инструменты разработки (HLS, ESL, ASIP и др.)
# - Доменно-ориентированное моделирование, совместное моделирование, метамоделирование компьютерных и кибер-физических систем
# - Модели, методы и средства исследования эффективности функционирования компьютерных и кибер-физических систем различных классов
# - Методы и средства повышения надежности и безопасности компьютерных и кибер-физических систем
# - Исследование современных компьютерных и сетевых технологий, их сравнительный анализ.
# ------------------------------------------------------------
# [chunk 0] sim=0.5389 meta={'column_title': 'Секции__Искусственный интеллект__Системы искусственного интеллекта и больших данных'}
# Секция соответствует магистерским программам "Проектирование и разработка систем искусственного интеллекта" и "Проектирование и разработка систем больших данных" по направлению подготовки "09.04.04 Программная инженерия", реализуемым факультетом ПИиКТ.
#
# Направления работы секции:
# Архитектура систем обработки больших данных
# Хранение и алгоритмы сжатия данных
# Структуры и алгоритмы индексации данных
# Надежность систем хранения данных
# Параллельная и распределенная обработка больших данных NoSQL хранилища данных
# Архитектура систем искусственного интеллекта
# Продвинутое машинное обучение и глубокое обучение
# Обработка изображений и компьютерное зрение
# Обработка звука и речи
# Анализ текстов
# Анализ потоковых данных
# Распределенное машинное обучение MLOps
# Валидация и тестирование систем искусственного интеллекта.
# Языки секции: русский, английский.
# ------------------------------------------------------------
# [chunk 0] sim=0.5335 meta={'column_title': 'Секции__Информационные технологии__Информационная безопасность, проектирование, технология элементов и узлов компьютерных систем'}
# Секция «Информационная безопасность, проектирование, технология элементов и узлов компьютерных систем» посвящена вопросам обеспечения безопасности современных систем обработки, хранения и передачи информации.
# Секция охватывает следующие актуальные проблемы:
# сетевая безопасность;
# обеспечение безопасности баз данных;
# безопасность мобильных систем;
# антивирусные средства защиты;
# системы управления доступом;
# криптографические методы защиты информации;
# другие аспекты информационной безопасности.
# К участию приглашаются молодые ученые, аспиранты, магистранты и бакалавры для апробации результатов своих научных работ и проектов.
# Секция является площадкой для обсуждения актуальных угроз безопасности и изучения новых технологий защиты
# современных систем.
# ------------------------------------------------------------
# [chunk 1] sim=0.4602 meta={'column_title': 'Секции__Физика и Инженерия__Современные функциональные материалы для устройств передачи данных'}
# Создание современных устройств передачи данных начинается с выбора оптимальных материалов и их структур, основываясь на конструкции и характеристиках разрабатываемого прибора.
# Помимо традиционных полупроводниковых материалов, которые выступают в роли рабочего тела устройства, конструирование приборов передачи данных включает исследование:
# металлических материалов;
# композитных материалов;
# полимерных материалов.
# Эти материалы используются для отвода тепла, корпусирования, защиты устройства и подвода питания.
# Секция посвящена вопросам исследования, синтеза, обработки и применения новых функциональных материалов в устройствах передачи данных.
# ------------------------------------------------------------
# [chunk 2] sim=0.4561 meta={'column_title': 'Секции__Физика и Инженерия__Современные функциональные материалы для устройств передачи данных'}
# Создание современных устройств передачи данных начинается с выбора оптимальных материалов и их структур, основываясь на конструкции и характеристиках разрабатываемого прибора.
# Помимо традиционных полупроводниковых материалов, которые выступают в роли рабочего тела устройства, конструирование приборов передачи данных включает исследование:
# металлических материалов;
# композитных материалов;
# полимерных материалов.
# Эти материалы используются для отвода тепла, корпусирования, защиты устройства и подвода питания.
# Секция посвящена вопросам исследования, синтеза, обработки и применения новых функциональных материалов в устройствах передачи данных.
# ------------------------------------------------------------
# [chunk 2] sim=0.4483 meta={'column_title': 'Секции__Физика и Инженерия__Компьютерные и кибер-физические системы, сети и технологии'}
# Новые архитектурные решения и принципы структурно-функциональной организации компьютерных и кибер-физических систем
# - Реконфигурируемые и адаптивные системы
# -Высокопроизводительные вычисления, параллельное и распределенное программирование, облачные вычисления и виртуализация
# - Методология проектирования и разработки компьютерных и кибер-физических систем. Системы автоматизированного проектирования
# - Встроенные системы и системы реального времени. Интернет вещей. - Повсеместные вычисления. Мобильные вычислительные системы
# - Универсальные и специализированные процессоры, системы на кристалле, программируемая логика. Современные инструменты разработки (HLS, ESL, ASIP и др.)
# - Доменно-ориентированное моделирование, совместное моделирование, метамоделирование компьютерных и кибер-физических систем
# - Модели, методы и средства исследования эффективности функционирования компьютерных и кибер-физических систем различных классов
# - Методы и средства повышения надежности и безопасности компьютерных и кибер-физических систем
# - Исследование современных компьютерных и сетевых технологий, их сравнительный анализ.
# ------------------------------------------------------------
# [chunk 2] sim=0.4483 meta={'column_title': 'Положение'}
# https://drive.google.com/file/d/1KvIKEgQm8LMLEd-fdMFbmY5WzG0RLWLi/view
# ------------------------------------------------------------
# [chunk 1] sim=0.4335 meta={'column_title': 'Секции__Физика и Инженерия__Компьютерные и кибер-физические системы, сети и технологии'}
# Новые архитектурные решения и принципы структурно-функциональной организации компьютерных и кибер-физических систем
# - Реконфигурируемые и адаптивные системы
# -Высокопроизводительные вычисления, параллельное и распределенное программирование, облачные вычисления и виртуализация
# - Методология проектирования и разработки компьютерных и кибер-физических систем. Системы автоматизированного проектирования
# - Встроенные системы и системы реального времени. Интернет вещей. - Повсеместные вычисления. Мобильные вычислительные системы
# - Универсальные и специализированные процессоры, системы на кристалле, программируемая логика. Современные инструменты разработки (HLS, ESL, ASIP и др.)
# - Доменно-ориентированное моделирование, совместное моделирование, метамоделирование компьютерных и кибер-физических систем
# - Модели, методы и средства исследования эффективности функционирования компьютерных и кибер-физических систем различных классов
# - Методы и средства повышения надежности и безопасности компьютерных и кибер-физических систем
# - Исследование современных компьютерных и сетевых технологий, их сравнительный анализ.
# ------------------------------------------------------------

# %% [markdown]
# # № 2  All text

# %%
article_emb = embed_fn([article_text])[0]          # (dim,)
article_emb_norm = article_emb / np.linalg.norm(article_emb)

# вычисляем sims к каждому документу:
sims = col_embs_norm.dot(article_emb_norm)         # (N_docs,)
best_idx = np.argsort(-sims)[:top_k]

print("\n=== Результаты поиска по всему тексту статьи ===")
for idx in best_idx:
    print(f"sim={sims[idx]:.4f} meta={mds[idx]}")
    print(docs[idx])
    print('-'*60)
# Out:
# === Результаты поиска по всему тексту статьи ===
# sim=0.5159 meta={'column_title': 'Секции__Искусственный интеллект__Системы искусственного интеллекта и больших данных'}
# Секция соответствует магистерским программам "Проектирование и разработка систем искусственного интеллекта" и "Проектирование и разработка систем больших данных" по направлению подготовки "09.04.04 Программная инженерия", реализуемым факультетом ПИиКТ.
#
# Направления работы секции:
# Архитектура систем обработки больших данных
# Хранение и алгоритмы сжатия данных
# Структуры и алгоритмы индексации данных
# Надежность систем хранения данных
# Параллельная и распределенная обработка больших данных NoSQL хранилища данных
# Архитектура систем искусственного интеллекта
# Продвинутое машинное обучение и глубокое обучение
# Обработка изображений и компьютерное зрение
# Обработка звука и речи
# Анализ текстов
# Анализ потоковых данных
# Распределенное машинное обучение MLOps
# Валидация и тестирование систем искусственного интеллекта.
# Языки секции: русский, английский.
# ------------------------------------------------------------
# sim=0.5149 meta={'column_title': 'Секции__Физика и Инженерия__Компьютерные и кибер-физические системы, сети и технологии'}
# Новые архитектурные решения и принципы структурно-функциональной организации компьютерных и кибер-физических систем
# - Реконфигурируемые и адаптивные системы
# -Высокопроизводительные вычисления, параллельное и распределенное программирование, облачные вычисления и виртуализация
# - Методология проектирования и разработки компьютерных и кибер-физических систем. Системы автоматизированного проектирования
# - Встроенные системы и системы реального времени. Интернет вещей. - Повсеместные вычисления. Мобильные вычислительные системы
# - Универсальные и специализированные процессоры, системы на кристалле, программируемая логика. Современные инструменты разработки (HLS, ESL, ASIP и др.)
# - Доменно-ориентированное моделирование, совместное моделирование, метамоделирование компьютерных и кибер-физических систем
# - Модели, методы и средства исследования эффективности функционирования компьютерных и кибер-физических систем различных классов
# - Методы и средства повышения надежности и безопасности компьютерных и кибер-физических систем
# - Исследование современных компьютерных и сетевых технологий, их сравнительный анализ.
# ------------------------------------------------------------
# sim=0.5149 meta={'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__ФИРМЫ И РЫНКИ: IT-решения для бизнеса / FIRM AND MARKETS: IT-driven solutions'}
# Секция посвящена исследованиям в области инновационных IT-решений, цифровой трансформации и устойчивого развития бизнеса.
# В центре внимания — технологии больших данных, искусственного интеллекта, организационных инноваций, автоматизации и блокчейна, а также их роль в повышении эффективности управления компаниями. Участники обсудят примеры внедрения цифровых решений в различных секторах экономики, включая ритейл, финансы и производство.
# Исследования затрагивают аспекты взаимодействия IT-инноваций с организационной культурой и стратегиями компаний. Особое внимание будет уделено цифровым экосистемам, платформенным бизнес-моделям и новым инструментам анализа поведения потребителей.
# ------------------------------------------------------------
# sim=0.5125 meta={'column_title': 'Секции__Искусственный интеллект__Аналитика данных'}
# Секция «Аналитика данных» Конгресса молодых ученых Университета ИТМО направлена на продвижение научных и промышленных исследовательских проектов, связанных с интеллектуальным анализом данных.
# Особое внимание уделяется применению современных методов машинного обучения и искусственного интеллекта для выявления прогнозов и неочевидных зависимостей в данных. Современная аналитика данных сочетает в себе мощь математики, статистики и искусственного интеллекта, предоставляя эффективные инструменты для решения задач различного масштаба — от обработки и анализа больших массивов данных до моделирования сложных процессов. Навыки анализа данных находят применение в самых разнообразных сферах: от научных исследований до бизнеса и образования.
# Ключевые направления секции:
# Классическое машинное обучение и алгоритмы обработки данных
# Обсуждение методов оптимизации алгоритмов машинного обучения, их интерпретации и применения для работы с разнообразными наборами данных.
# Глубокое обучение и его применения
# Исследования в области нейронных сетей, включая обучение с подкреплением, работу с большими архитектурами и их адаптацию для решения реальных задач.
# Графовые нейронные сети и алгоритмы на графах
# Алгоритмы обработки графовых структур и использование GNN для анализа сложных связей в социальных сетях, биоинформатике, логистике и других областях.
# Обработка естественного языка (NLP)
# Технологии анализа текстовых данных, включая автоматическое распознавание, тематическое моделирование, построение диалоговых систем и извлечение знаний из текстов.
# Обработка изображений и компьютерное зрение
# Решение задач сегментации, классификации и генерации изображений, а также применение глубоких архитектур для обработки визуальных данных.
# Анализ звука и речи
# Актуальные разработки в области распознавания речи, генерации аудио и улучшения качества звуковых данных.
# Системы управления базами данных (СУБД)
# Разработка решений для эффективного хранения, обработки и анализа структурированных и неструктурированных данных. Особое внимание уделяется гибридным подходам и оптимизации запросов.
# Участники секции приглашаются представить свои исследования и проекты в указанных направлениях, обогатив общий обзор современных достижений в области аналитики данных.
# Секция «Аналитика данных» приглашает всех заинтересованных ознакомиться с более подробной информацией о ключевых направлениях исследований на нашем веб-сайте [https://dc.itmo.ru/analytic_master].
# ------------------------------------------------------------
# sim=0.5116 meta={'column_title': 'Секции__Искусственный интеллект__Scientific Open-Source Meetup: Открытый код для ИИ'}
# Секция посвящена реализации методов и моделей искусственного интеллекта в рамках библиотек с открытым исходным кодом.
# Мы принимаем доклады на следующие темы:
# опыт создания конкретных open-source разработок;
# истории успехов и неудач, связанных с участием в OS-проектах, а также «лучшие практики» в области создания открытого ПО;
# анонсы научных проектов (в формате мини-презентации на 3–5 минут), открытых для стороннего участия.
# Также в рамках секции планируется проведение неформальной дискуссии, посвящённой различным аспектам разработки открытого программного обеспечения.
# Секция реализуется факультетом технологий искусственного интеллекта и соответствует программам магистратуры:
# «Искусственный интеллект в промышленности»;
# «Искусственный интеллект и поведенческая экономика»;
# «Большие данные и машинное обучение».
# К участию приглашаются молодые ученые, магистранты и бакалавры различных направлений подготовки (не только IT, но и прикладные науки и другие области), которые заинтересованы в участии в существующих open-source разработках, а также в создании собственных проектов.
# ------------------------------------------------------------

# %% [markdown]
# # №3 Chunks + Keywords

# %%
from typing import List
import re
from collections import Counter

import nltk
nltk.download('stopwords')  # если ещё не скачали стоп‑слова
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fortn/nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
# 1) Функция для извлечения ключевых слов из произвольного текста
def extract_keywords(text: str, top_k: int = 10) -> List[str]:
    russian_stopwords = set(stopwords.words('russian'))
    # собираем все «слова» длиной >3, убираем стоп‑слова
    words = re.findall(r'\w+', text.lower())
    filtered = [w for w in words if w not in russian_stopwords and len(w) > 3]
    # считаем частоты и берём top_k
    freq = Counter(filtered)
    return [w for w, _ in freq.most_common(top_k)]

# %%
# 2) Извлекаем ключевые слова для каждого чанка
chunk_keywords = [extract_keywords(chunk, top_k=8) for chunk in chunks]

# 3) Подгружаем из коллекции все документы + эмбеддинги + метаданные
contents = collection.get(include=['embeddings', 'documents', 'metadatas'])
col_embs = np.array(contents['embeddings'])    # shape (N_docs, dim)
docs     = contents['documents']               # List[str]
mds      = contents['metadatas']

# %%
# Нормализуем эмбеддинги коллекции
col_embs_norm = col_embs / np.linalg.norm(col_embs, axis=1, keepdims=True)

results = []

# %%
# 4) Для каждого чанка:
for idx_chunk, (chunk_emb, kws) in enumerate(zip(chunk_embeddings, chunk_keywords)):
    # 4.1) находим из коллекции документы, где есть хотя бы одно ключевое слово
    matching_idx = [
        i for i, doc in enumerate(docs)
        if any(kw in doc.lower() for kw in kws)
    ]
    if not matching_idx:
        # если ничего не нашли по ключевым словам, используем всю коллекцию
        matching_idx = list(range(len(docs)))

    # готовим подмножество эмбеддингов и текстов
    subset_embs_norm = col_embs_norm[matching_idx]
    subset_docs      = [docs[i] for i in matching_idx]
    subset_mds       = [mds[i] for i in matching_idx]

    # нормализуем текущий чанк
    emb_norm = chunk_emb / np.linalg.norm(chunk_emb)

    # 4.2) считаем косинусную похожесть
    sims = subset_embs_norm.dot(emb_norm)  # (len(matching_idx),)

    # 4.3) берём top_k по сходству
    top_k = 5
    best_pos = np.argsort(-sims)[:top_k]
    for pos in best_pos:
        orig_i = matching_idx[pos]
        results.append({
            'chunk_index': idx_chunk,
            'keywords':       kws,
            'similarity':     float(sims[pos]),
            'text':           subset_docs[pos],
            'metadata':       subset_mds[pos]
        })

# 5) Сортируем все результаты сразу
results = sorted(results, key=lambda x: -x['similarity'])

# 6) Выводим топ‑10
for r in results[:10]:
    print(f"[chunk {r['chunk_index']}] sim={r['similarity']:.4f} keys={r['keywords']}")
    print(r['metadata'])
    print(r['text'])
    print('-'*60)
# Out:
# [chunk 0] sim=0.5526 keys=['данных', 'блоков', 'хранения', 'системы', 'систем', 'распределенных', 'реестров', 'блока']
# {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__ФИРМЫ И РЫНКИ: IT-решения для бизнеса / FIRM AND MARKETS: IT-driven solutions'}
# Секция посвящена исследованиям в области инновационных IT-решений, цифровой трансформации и устойчивого развития бизнеса.
# В центре внимания — технологии больших данных, искусственного интеллекта, организационных инноваций, автоматизации и блокчейна, а также их роль в повышении эффективности управления компаниями. Участники обсудят примеры внедрения цифровых решений в различных секторах экономики, включая ритейл, финансы и производство.
# Исследования затрагивают аспекты взаимодействия IT-инноваций с организационной культурой и стратегиями компаний. Особое внимание будет уделено цифровым экосистемам, платформенным бизнес-моделям и новым инструментам анализа поведения потребителей.
# ------------------------------------------------------------
# [chunk 0] sim=0.5443 keys=['данных', 'блоков', 'хранения', 'системы', 'систем', 'распределенных', 'реестров', 'блока']
# {'column_title': 'Секции__Искусственный интеллект__Аналитика данных'}
# Секция «Аналитика данных» Конгресса молодых ученых Университета ИТМО направлена на продвижение научных и промышленных исследовательских проектов, связанных с интеллектуальным анализом данных.
# Особое внимание уделяется применению современных методов машинного обучения и искусственного интеллекта для выявления прогнозов и неочевидных зависимостей в данных. Современная аналитика данных сочетает в себе мощь математики, статистики и искусственного интеллекта, предоставляя эффективные инструменты для решения задач различного масштаба — от обработки и анализа больших массивов данных до моделирования сложных процессов. Навыки анализа данных находят применение в самых разнообразных сферах: от научных исследований до бизнеса и образования.
# Ключевые направления секции:
# Классическое машинное обучение и алгоритмы обработки данных
# Обсуждение методов оптимизации алгоритмов машинного обучения, их интерпретации и применения для работы с разнообразными наборами данных.
# Глубокое обучение и его применения
# Исследования в области нейронных сетей, включая обучение с подкреплением, работу с большими архитектурами и их адаптацию для решения реальных задач.
# Графовые нейронные сети и алгоритмы на графах
# Алгоритмы обработки графовых структур и использование GNN для анализа сложных связей в социальных сетях, биоинформатике, логистике и других областях.
# Обработка естественного языка (NLP)
# Технологии анализа текстовых данных, включая автоматическое распознавание, тематическое моделирование, построение диалоговых систем и извлечение знаний из текстов.
# Обработка изображений и компьютерное зрение
# Решение задач сегментации, классификации и генерации изображений, а также применение глубоких архитектур для обработки визуальных данных.
# Анализ звука и речи
# Актуальные разработки в области распознавания речи, генерации аудио и улучшения качества звуковых данных.
# Системы управления базами данных (СУБД)
# Разработка решений для эффективного хранения, обработки и анализа структурированных и неструктурированных данных. Особое внимание уделяется гибридным подходам и оптимизации запросов.
# Участники секции приглашаются представить свои исследования и проекты в указанных направлениях, обогатив общий обзор современных достижений в области аналитики данных.
# Секция «Аналитика данных» приглашает всех заинтересованных ознакомиться с более подробной информацией о ключевых направлениях исследований на нашем веб-сайте [https://dc.itmo.ru/analytic_master].
# ------------------------------------------------------------
# [chunk 0] sim=0.5420 keys=['данных', 'блоков', 'хранения', 'системы', 'систем', 'распределенных', 'реестров', 'блока']
# {'column_title': 'Секции__Физика и Инженерия__Компьютерные и кибер-физические системы, сети и технологии'}
# Новые архитектурные решения и принципы структурно-функциональной организации компьютерных и кибер-физических систем
# - Реконфигурируемые и адаптивные системы
# -Высокопроизводительные вычисления, параллельное и распределенное программирование, облачные вычисления и виртуализация
# - Методология проектирования и разработки компьютерных и кибер-физических систем. Системы автоматизированного проектирования
# - Встроенные системы и системы реального времени. Интернет вещей. - Повсеместные вычисления. Мобильные вычислительные системы
# - Универсальные и специализированные процессоры, системы на кристалле, программируемая логика. Современные инструменты разработки (HLS, ESL, ASIP и др.)
# - Доменно-ориентированное моделирование, совместное моделирование, метамоделирование компьютерных и кибер-физических систем
# - Модели, методы и средства исследования эффективности функционирования компьютерных и кибер-физических систем различных классов
# - Методы и средства повышения надежности и безопасности компьютерных и кибер-физических систем
# - Исследование современных компьютерных и сетевых технологий, их сравнительный анализ.
# ------------------------------------------------------------
# [chunk 0] sim=0.5389 keys=['данных', 'блоков', 'хранения', 'системы', 'систем', 'распределенных', 'реестров', 'блока']
# {'column_title': 'Секции__Искусственный интеллект__Системы искусственного интеллекта и больших данных'}
# Секция соответствует магистерским программам "Проектирование и разработка систем искусственного интеллекта" и "Проектирование и разработка систем больших данных" по направлению подготовки "09.04.04 Программная инженерия", реализуемым факультетом ПИиКТ.
#
# Направления работы секции:
# Архитектура систем обработки больших данных
# Хранение и алгоритмы сжатия данных
# Структуры и алгоритмы индексации данных
# Надежность систем хранения данных
# Параллельная и распределенная обработка больших данных NoSQL хранилища данных
# Архитектура систем искусственного интеллекта
# Продвинутое машинное обучение и глубокое обучение
# Обработка изображений и компьютерное зрение
# Обработка звука и речи
# Анализ текстов
# Анализ потоковых данных
# Распределенное машинное обучение MLOps
# Валидация и тестирование систем искусственного интеллекта.
# Языки секции: русский, английский.
# ------------------------------------------------------------
# [chunk 0] sim=0.5335 keys=['данных', 'блоков', 'хранения', 'системы', 'систем', 'распределенных', 'реестров', 'блока']
# {'column_title': 'Секции__Информационные технологии__Информационная безопасность, проектирование, технология элементов и узлов компьютерных систем'}
# Секция «Информационная безопасность, проектирование, технология элементов и узлов компьютерных систем» посвящена вопросам обеспечения безопасности современных систем обработки, хранения и передачи информации.
# Секция охватывает следующие актуальные проблемы:
# сетевая безопасность;
# обеспечение безопасности баз данных;
# безопасность мобильных систем;
# антивирусные средства защиты;
# системы управления доступом;
# криптографические методы защиты информации;
# другие аспекты информационной безопасности.
# К участию приглашаются молодые ученые, аспиранты, магистранты и бакалавры для апробации результатов своих научных работ и проектов.
# Секция является площадкой для обсуждения актуальных угроз безопасности и изучения новых технологий защиты
# современных систем.
# ------------------------------------------------------------
# [chunk 2] sim=0.4483 keys=['ethereum', 'электронный', 'ресурс', 'режим', 'доступа', 'https', 'дата', 'обращения']
# {'column_title': 'Положение'}
# https://drive.google.com/file/d/1KvIKEgQm8LMLEd-fdMFbmY5WzG0RLWLi/view
# ------------------------------------------------------------
# [chunk 2] sim=0.4185 keys=['ethereum', 'электронный', 'ресурс', 'режим', 'доступа', 'https', 'дата', 'обращения']
# {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__ОБЩЕСТВО И ЦИФРОВОЕ НЕРАВЕНСТВО: Цифровые исследования в бизнесе и экономике / SOCIETY AND DIGITAL DIVIDE: Digital studies in Business and Economics'}
# Секция посвящена изучению явлений и взаимосвязей в бизнесе и экономике, которые становятся видимыми благодаря использованию цифровых данных. Основное внимание уделяется анализу цифровых следов, включая данные социальных сетей, интернет-платформ и транзакций, а также их роли в понимании социальных и экономических процессов. Участники обсудят результаты исследований с использованием современных методов анализа данных, таких как машинное обучение, текстовый анализ, сетевой анализ, методы обработки больших данных и т.д.
# В рамках секции будут также рассмотрены вопросы влияния цифровизации на экономическое развитие, поведение организаций и потребителей, а также цифровое неравенство как фактор, формирующий доступ к современным ресурсам и технологиям. Темы секции охватывают исследования цифровой экономики, динамики рыночных взаимодействий и трансформации бизнес-моделей, акцентируя внимание на междисциплинарных подходах и научной валидности представленных методов.
# ------------------------------------------------------------
# [chunk 1] sim=0.4102 keys=['меркла', 'узлов', 'дерева', 'патрициа', 'позволяет', 'node', 'блок', 'структура']
# {'column_title': 'Секции__Информационные технологии__Информационная безопасность, проектирование, технология элементов и узлов компьютерных систем'}
# Секция «Информационная безопасность, проектирование, технология элементов и узлов компьютерных систем» посвящена вопросам обеспечения безопасности современных систем обработки, хранения и передачи информации.
# Секция охватывает следующие актуальные проблемы:
# сетевая безопасность;
# обеспечение безопасности баз данных;
# безопасность мобильных систем;
# антивирусные средства защиты;
# системы управления доступом;
# криптографические методы защиты информации;
# другие аспекты информационной безопасности.
# К участию приглашаются молодые ученые, аспиранты, магистранты и бакалавры для апробации результатов своих научных работ и проектов.
# Секция является площадкой для обсуждения актуальных угроз безопасности и изучения новых технологий защиты
# современных систем.
# ------------------------------------------------------------
# [chunk 2] sim=0.4094 keys=['ethereum', 'электронный', 'ресурс', 'режим', 'доступа', 'https', 'дата', 'обращения']
# {'column_title': 'Секции__Искусственный интеллект__Аналитика данных'}
# Секция «Аналитика данных» Конгресса молодых ученых Университета ИТМО направлена на продвижение научных и промышленных исследовательских проектов, связанных с интеллектуальным анализом данных.
# Особое внимание уделяется применению современных методов машинного обучения и искусственного интеллекта для выявления прогнозов и неочевидных зависимостей в данных. Современная аналитика данных сочетает в себе мощь математики, статистики и искусственного интеллекта, предоставляя эффективные инструменты для решения задач различного масштаба — от обработки и анализа больших массивов данных до моделирования сложных процессов. Навыки анализа данных находят применение в самых разнообразных сферах: от научных исследований до бизнеса и образования.
# Ключевые направления секции:
# Классическое машинное обучение и алгоритмы обработки данных
# Обсуждение методов оптимизации алгоритмов машинного обучения, их интерпретации и применения для работы с разнообразными наборами данных.
# Глубокое обучение и его применения
# Исследования в области нейронных сетей, включая обучение с подкреплением, работу с большими архитектурами и их адаптацию для решения реальных задач.
# Графовые нейронные сети и алгоритмы на графах
# Алгоритмы обработки графовых структур и использование GNN для анализа сложных связей в социальных сетях, биоинформатике, логистике и других областях.
# Обработка естественного языка (NLP)
# Технологии анализа текстовых данных, включая автоматическое распознавание, тематическое моделирование, построение диалоговых систем и извлечение знаний из текстов.
# Обработка изображений и компьютерное зрение
# Решение задач сегментации, классификации и генерации изображений, а также применение глубоких архитектур для обработки визуальных данных.
# Анализ звука и речи
# Актуальные разработки в области распознавания речи, генерации аудио и улучшения качества звуковых данных.
# Системы управления базами данных (СУБД)
# Разработка решений для эффективного хранения, обработки и анализа структурированных и неструктурированных данных. Особое внимание уделяется гибридным подходам и оптимизации запросов.
# Участники секции приглашаются представить свои исследования и проекты в указанных направлениях, обогатив общий обзор современных достижений в области аналитики данных.
# Секция «Аналитика данных» приглашает всех заинтересованных ознакомиться с более подробной информацией о ключевых направлениях исследований на нашем веб-сайте [https://dc.itmo.ru/analytic_master].
# ------------------------------------------------------------
# [chunk 1] sim=0.3974 keys=['меркла', 'узлов', 'дерева', 'патрициа', 'позволяет', 'node', 'блок', 'структура']
# {'column_title': 'Секции__Будущее экономики в эпоху технологических изменений: роль искусственного интеллекта и инноваций__ФИРМЫ И РЫНКИ: IT-решения для бизнеса / FIRM AND MARKETS: IT-driven solutions'}
# Секция посвящена исследованиям в области инновационных IT-решений, цифровой трансформации и устойчивого развития бизнеса.
# В центре внимания — технологии больших данных, искусственного интеллекта, организационных инноваций, автоматизации и блокчейна, а также их роль в повышении эффективности управления компаниями. Участники обсудят примеры внедрения цифровых решений в различных секторах экономики, включая ритейл, финансы и производство.
# Исследования затрагивают аспекты взаимодействия IT-инноваций с организационной культурой и стратегиями компаний. Особое внимание будет уделено цифровым экосистемам, платформенным бизнес-моделям и новым инструментам анализа поведения потребителей.
# ------------------------------------------------------------

# %% [markdown]
# # №4 Chunks + Keywords

# %%
from transformers import pipeline

# %%
embed_fn = processor.get_embedding_function()

# 1. Извлечение ключевых слов из статьи
def extract_keywords(text: str, top_k: int = 10) -> List[str]:
    # Здесь можно подгрузить стоп‑слова русского языка
    russian_stopwords = set(stopwords.words('russian'))
    words = re.findall(r'\w+', text.lower())
    filtered = [w for w in words if w not in russian_stopwords and len(w) > 3]
    freq = Counter(filtered)
    return [w for w, _ in freq.most_common(top_k)]

keywords = extract_keywords(article_text, top_k=8)
print("Ключевые слова статьи:", keywords)
# Out:
# Ключевые слова статьи: ['данных', 'меркла', 'хранения', 'дерева', 'блока', 'блоков', 'позволяет', 'является']

# %%
# 2. Генерация сводки с учётом ключевых слов
summarizer = pipeline(
    "summarization",
    model="facebook/bart-large-cnn",
    tokenizer="facebook/bart-large-cnn",
    device=0  # или -1, если без GPU
)

# Собираем подсказку (prompt), чтобы в summary попали ключевые слова
prompt = (
    "Сгенерируй краткую сводку следующего текста так, "
    "чтобы в ней были использованы эти ключевые слова: "
    f"{', '.join(keywords)}.\n\nТекст статьи:\n{article_text}"
)
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
