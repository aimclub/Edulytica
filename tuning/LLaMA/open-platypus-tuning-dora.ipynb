# %%
# !pip install -q -U transformers peft accelerate datasets trl bitsandbytes
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.4.1 requires cubinlinker, which is not installed.
# cudf 24.4.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.4.1 requires ptxcompiler, which is not installed.
# cuml 24.4.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.4.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 16.1.0 which is incompatible.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.2.1 which is incompatible.
# cudf 24.4.1 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.5.0 which is incompatible.
# cudf 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# rapids-dask-dependency 24.4.1a0 requires dask==2024.1.1, but you have dask 2024.5.2 which is incompatible.
# rapids-dask-dependency 24.4.1a0 requires dask-expr==0.4.0, but you have dask-expr 1.1.2 which is incompatible.

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, prepare_model_for_kbit_training, PeftModel
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    TrainingArguments,
    BitsAndBytesConfig
)
from trl import SFTTrainer
# Out:
# 2024-07-01 11:43:07.652280: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-01 11:43:07.652390: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-01 11:43:07.771255: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Load Platypus dataset
data_name = "jester20/data0"
dataset = load_dataset(data_name, split="train")
dataset
# Out:
# Downloading readme:   0%|          | 0.00/316 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.25M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Dataset({
#     features: ['instruction', 'output'],
#     num_rows: 1000
# })

# %%
# Set model names
model_name = "NousResearch/Llama-2-7b-chat-hf"
refined_model = "Megnis/saiga_llama3_8b-qdora-4bit"
# Out:
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]

# %%
if torch.cuda.is_bf16_supported():
  # !pip install flash_attn
  compute_dtype = torch.bfloat16
  attn_implementation = 'flash_attention_2'
else:
  compute_dtype = torch.float16
  attn_implementation = 'sdpa'


# Load Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = 'left' #Necessary for FlashAttention compatibility
# Set Quantization config
bnb_config = BitsAndBytesConfig(
        load_in_8bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=False,
)
# Load model
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}, torch_dtype=compute_dtype, use_cache=False, attn_implementation=attn_implementation
)
model.config.pretraining_tp = 1

model = prepare_model_for_kbit_training(model)
model.gradient_checkpointing_enable({'use_reentrant':True})
# Out:
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("huggingface")

from huggingface_hub import login
login(secret_value_0)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# Set Training Config
peft_config = LoraConfig(
        lora_alpha=15,
        lora_dropout=0.1,
        bias="none",
        use_dora=True,
        task_type="CAUSAL_LM",
)


training_arguments = TrainingArguments(
        output_dir="./qdora2/",
        #evaluation_strategy="steps",
        do_eval=True,
        optim="paged_adamw_32bit",
        per_device_train_batch_size=1,
        per_device_eval_batch_size=1,
        #log_level="debug",
        logging_steps=25,
        learning_rate=2e-4,
        #eval_steps=25,
        num_train_epochs=1,
        fp16= False,
        bf16= False,
        max_grad_norm=0.3,
        max_steps=-1,
        save_strategy='epoch',
        warmup_ratio=0.03,
        warmup_steps=10,
        lr_scheduler_type="linear",
        #push_to_hub = True
)
# Load Triner
trainer = SFTTrainer(
        model=model,
        train_dataset=dataset,
        eval_dataset=dataset,
        dataset_text_field="instruction",
        #max_seq_length=4096,
        peft_config=peft_config,
        tokenizer=tokenizer,
        args=training_arguments,
)
# Implement training loop
trainer.train()
# Out:
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': dataset_text_field. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1961: FutureWarning: `--push_to_hub_token` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--hub_token` instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1961: FutureWarning: `--push_to_hub_token` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--hub_token` instead.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[8], line 33
#       1 peft_config = LoraConfig(
#       2         lora_alpha=15,
#       3         lora_dropout=0.1,
#    (...)
#       6         task_type="CAUSAL_LM",
#       7 )
#      10 training_arguments = TrainingArguments(
#      11         output_dir="./qdora2/",
#      12         #evaluation_strategy="steps",
#    (...)
#      30         #push_to_hub = True
#      31 )
# ---> 33 trainer = SFTTrainer(
#      34         model=model,
#      35         train_dataset=dataset,
#      36         eval_dataset=dataset,
#      37         dataset_text_field="instruction",
#      38         #max_seq_length=4096,
#      39         peft_config=peft_config,
#      40         tokenizer=tokenizer,
#      41         args=training_arguments,
#      42 )
#      44 trainer.train()
#
# File /opt/conda/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py:101, in _deprecate_arguments.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      99         message += "\n\n" + custom_message
#     100     warnings.warn(message, FutureWarning)
# --> 101 return f(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:254, in SFTTrainer.__init__(self, model, args, data_collator, train_dataset, eval_dataset, tokenizer, model_init, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics, peft_config, dataset_text_field, packing, formatting_func, max_seq_length, infinite, num_of_sequences, chars_per_token, dataset_num_proc, dataset_batch_size, neftune_noise_alpha, model_init_kwargs, dataset_kwargs, eval_packing)
#     252     model = get_peft_model(model, peft_config, autocast_adapter_dtype=False)
#     253 else:
# --> 254     model = get_peft_model(model, peft_config)
#     255 if (
#     256     args is not None
#     257     and args.bf16
#     258     and getattr(model, "is_loaded_in_4bit", False)
#     259     and not is_sharded_qlora
#     260 ):
#     261     peft_module_casting_to_bf16(model)
#
# File /opt/conda/lib/python3.10/site-packages/peft/mapping.py:149, in get_peft_model(model, peft_config, adapter_name, mixed)
#     147 if peft_config.is_prompt_learning:
#     148     peft_config = _prepare_prompt_learning_config(peft_config, model_config)
# --> 149 return MODEL_TYPE_TO_PEFT_MODEL_MAPPING[peft_config.task_type](model, peft_config, adapter_name=adapter_name)
#
# File /opt/conda/lib/python3.10/site-packages/peft/peft_model.py:1395, in PeftModelForCausalLM.__init__(self, model, peft_config, adapter_name)
#    1394 def __init__(self, model: torch.nn.Module, peft_config: PeftConfig, adapter_name: str = "default") -> None:
# -> 1395     super().__init__(model, peft_config, adapter_name)
#    1396     self.base_model_prepare_inputs_for_generation = self.base_model.prepare_inputs_for_generation
#
# File /opt/conda/lib/python3.10/site-packages/peft/peft_model.py:138, in PeftModel.__init__(self, model, peft_config, adapter_name)
#     136     self._peft_config = None
#     137     cls = PEFT_TYPE_TO_MODEL_MAPPING[peft_config.peft_type]
# --> 138     self.base_model = cls(model, {adapter_name: peft_config}, adapter_name)
#     139     self.set_additional_trainable_modules(peft_config, adapter_name)
#     141 if getattr(model, "is_gradient_checkpointing", True):
#
# File /opt/conda/lib/python3.10/site-packages/peft/tuners/lora/model.py:139, in LoraModel.__init__(self, model, config, adapter_name)
#     138 def __init__(self, model, config, adapter_name) -> None:
# --> 139     super().__init__(model, config, adapter_name)
#
# File /opt/conda/lib/python3.10/site-packages/peft/tuners/tuners_utils.py:166, in BaseTuner.__init__(self, model, peft_config, adapter_name)
#     164 self.active_adapter: str | list[str] = adapter_name
#     165 self._pre_injection_hook(self.model, self.peft_config[adapter_name], adapter_name)
# --> 166 self.inject_adapter(self.model, adapter_name)
#     168 # Copy the peft_config in the injected model.
#     169 self.model.peft_config = self.peft_config
#
# File /opt/conda/lib/python3.10/site-packages/peft/tuners/tuners_utils.py:372, in BaseTuner.inject_adapter(self, model, adapter_name)
#     370     is_target_modules_in_base_model = True
#     371     parent, target, target_name = _get_submodules(model, key)
# --> 372     self._create_and_replace(peft_config, adapter_name, target, target_name, parent, current_key=key)
#     374 if not is_target_modules_in_base_model:
#     375     raise ValueError(
#     376         f"Target modules {peft_config.target_modules} not found in the base model. "
#     377         f"Please check the target modules and try again."
#     378     )
#
# File /opt/conda/lib/python3.10/site-packages/peft/tuners/lora/model.py:223, in LoraModel._create_and_replace(self, lora_config, adapter_name, target, target_name, parent, current_key)
#     213     target.update_layer(
#     214         adapter_name,
#     215         r,
#    (...)
#     220         use_dora=lora_config.use_dora,
#     221     )
#     222 else:
# --> 223     new_module = self._create_new_module(lora_config, adapter_name, target, **kwargs)
#     224     if adapter_name not in self.active_adapters:
#     225         # adding an additional adapter: it is not automatically trainable
#     226         new_module.requires_grad_(False)
#
# File /opt/conda/lib/python3.10/site-packages/peft/tuners/lora/model.py:314, in LoraModel._create_new_module(lora_config, adapter_name, target, **kwargs)
#     312 new_module = None
#     313 for dispatcher in dispatchers:
# --> 314     new_module = dispatcher(target, adapter_name, lora_config=lora_config, **kwargs)
#     315     if new_module is not None:  # first match wins
#     316         break
#
# File /opt/conda/lib/python3.10/site-packages/peft/tuners/lora/bnb.py:267, in dispatch_bnb_8bit(target, adapter_name, **kwargs)
#     258     eightbit_kwargs = kwargs.copy()
#     259     eightbit_kwargs.update(
#     260         {
#     261             "has_fp16_weights": target.state.has_fp16_weights,
#    (...)
#     265         }
#     266     )
# --> 267     new_module = Linear8bitLt(target, adapter_name, **eightbit_kwargs)
#     269 return new_module
#
# File /opt/conda/lib/python3.10/site-packages/peft/tuners/lora/bnb.py:51, in Linear8bitLt.__init__(self, base_layer, adapter_name, r, lora_alpha, lora_dropout, init_lora_weights, use_rslora, use_dora, **kwargs)
#      48 self.fan_in_fan_out = False
#      50 self._active_adapter = adapter_name
# ---> 51 self.update_layer(
#      52     adapter_name,
#      53     r,
#      54     lora_alpha=lora_alpha,
#      55     lora_dropout=lora_dropout,
#      56     init_lora_weights=init_lora_weights,
#      57     use_rslora=use_rslora,
#      58     use_dora=use_dora,
#      59 )
#
# File /opt/conda/lib/python3.10/site-packages/peft/tuners/lora/layer.py:135, in LoraLayer.update_layer(self, adapter_name, r, lora_alpha, lora_dropout, init_lora_weights, use_rslora, use_dora)
#     132         break
#     134 if use_dora:
# --> 135     self.dora_init(adapter_name)
#     136     self.use_dora[adapter_name] = True
#     137 else:
#
# File /opt/conda/lib/python3.10/site-packages/peft/tuners/lora/layer.py:237, in LoraLayer.dora_init(self, adapter_name)
#     235 with gather_params_ctx(self.get_base_layer().parameters()):
#     236     base_layer = self.get_base_layer()
# --> 237     weight = dequantize_module_weight(base_layer)
#     238     if weight.data.ndim == 4:  # For handling LoRAs applied to Conv2Ds.
#     239         lora_weight = torch.mm(lora_B.flatten(start_dim=1), lora_A.flatten(start_dim=1))
#
# File /opt/conda/lib/python3.10/site-packages/peft/utils/integrations.py:64, in dequantize_module_weight(module)
#      62 device = weight.device
#      63 is_cpu = device.type == torch.device("cpu").type
# ---> 64 weight = dequantize_bnb_weight(weight, state=quant_state)  # no-op if not bnb
#      65 if is_cpu:
#      66     # dequantize_bnb_weight for 8bit moves the device in-place, thus we need to move it back to CPU if necessary
#      67     module.weight = module.weight.to(device)
#
# File /opt/conda/lib/python3.10/site-packages/peft/utils/integrations.py:99, in dequantize_bnb_weight(weight, state)
#      97 if state.CxB is None:
#      98     state.CxB, state.SB = bnb.functional.transform(weight.data, to_order=state.formatB)
# ---> 99 out32, Sout32 = bnb.functional.igemmlt(im, state.CxB, Sim, state.SB)
#     100 dequantized = bnb.functional.mm_dequant(out32, Sout32, SCim, state.SCB, bias=None).t()
#     101 if is_cpu:
#
# File /opt/conda/lib/python3.10/site-packages/bitsandbytes/functional.py:2333, in igemmlt(A, B, SA, SB, out, Sout, dtype)
#    2330         has_error = lib.cigemmlt_ampere_8(ptr, m, n, k, ptrA, ptrB, ptrC, ptrRowScale, lda, ldb, ldc)
#    2332 if has_error == 100:  # `ERR_NOT_IMPLEMENTED` is defined as 100 in `ops.cu`
# -> 2333     raise NotImplementedError("igemmlt not available (probably built with NO_CUBLASLT)")
#    2335 if has_error:
#    2336     print(f"A: {shapeA}, B: {shapeB}, C: {Sout[0]}; (lda, ldb, ldc): {(lda, ldb, ldc)}; (m, n, k): {(m, n, k)}")
#
# NotImplementedError: igemmlt not available (probably built with NO_CUBLASLT)

# %%
refined_model = "Megnis/qdora2"

# %%
# Save model
trainer.model.save_pretrained(refined_model)

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("huggingface")

from huggingface_hub import login
login(secret_value_0)

# %%
# Push model to hugginface hub
trainer.push_to_hub(refined_model)
